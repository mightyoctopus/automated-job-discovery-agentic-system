# %% [markdown]
# # SerpAPI Web Search

# %%
import os
import time
import serpapi
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
SERP_API_KEY = os.getenv("SERP_API_KEY")

# %%
serp_queries = [
    'site:greenhouse.io ("AI engineer" OR "LLM engineer" OR "Machine Learning Engineer") (remote OR "remote-friendly" OR worldwide OR APAC OR Asia OR "South Korea") (agentic OR "AI agent" OR "agentic systems" OR RAG OR "retrieval-augmented" OR LoRA OR QLoRA OR "fine-tune" OR "Hugging Face" OR "open-source") (junior OR entry OR internship OR mid)',
    'site:lever.co intitle:careers ("agentic" OR "AI agent" OR "RAG" OR "LoRA" OR "QLoRA" OR "fine-tune" OR "Hugging Face") (remote OR worldwide OR Asia OR APAC OR "South Korea") (junior OR intern OR mid OR "early career")',
    'inurl:/careers ("AI engineer" OR "LLM engineer" OR "AI integration" OR "LLM engineering") (remote OR "remote-friendly" OR global OR Asia OR APAC OR "South Korea") ("Hugging Face" OR "open-source" OR transformers OR LoRA OR QLoRA OR RAG)',
    '(inurl:jobs OR inurl:careers OR intitle:jobs) ("agentic systems" OR "AI agents" OR agents) (remote OR worldwide OR Asia OR APAC OR "South Korea") (junior OR internship OR mid)',
    'site:workable.com ("AI engineer" OR "LLM" OR "LLM engineer") (remote OR APAC OR Asia OR "South Korea" OR worldwide) (LoRA OR QLoRA OR RAG OR "retrieval-augmented" OR "Hugging Face") (junior OR mid OR intern)',
]

exa_queries = [
    'Find remote junior or mid AI engineer roles on company careers or ATS pages (Greenhouse, Lever, Workable, Greenhouse boards) focused on agentic systems, AI agents, RAG pipelines, LoRA/QLoRA fine-tuning, Hugging Face or open-source LLMs — worldwide or APAC including South Korea',
    'Company careers pages hiring interns or early-career LLM engineers for RAG pipelines, LoRA/QLoRA fine-tuning, agentic AI, or AI-driven app integration; remote-friendly roles accepting applicants from Asia/APAC or global',
    'Search for remote-friendly junior AI engineer jobs on in-house careers pages or static ATS pages (Greenhouse, Lever, Workable) that mention AI agents, agentic systems, retrieval-augmented generation, LoRA, QLoRA, Hugging Face or open-source models',
    'List mid-level or internship openings at companies with direct careers pages for LLM engineering, agentic systems, RAG, fine-tuning (LoRA/QLoRA), model integration, remote worldwide or Asia/APAC-friendly',
    'Find company job posts (careers/, jobs/ or boards.greenhouse.io) for remote LLM engineer or AI agent engineer, focusing on open-source Hugging Face models, LoRA/QLoRA fine-tuning, RAG, accepting applicants in Asia including South Korea',
]

# %%
import time

client = serpapi.Client(api_key=SERP_API_KEY)
all_results = []
for i, q in enumerate(serp_queries):
    response = client.search({
        "engine": "google", 
        "google_domain": "google.com",
        "hl": "en", 
        "q": q
    })

    # Flatten response into all_results list
    all_results.extend([
        {**item, "searched_via": "serp"} # Add a new key-value into the existing dict
        for item in response.get("organic_results", [])
   ])
    print(f"SerpAPI Search Interation {i + 1} Finished")
    time.sleep(1)
# Out:
# SerpAPI Search Interation 1 Finished
# SerpAPI Search Interation 2 Finished
# SerpAPI Search Interation 3 Finished
# SerpAPI Search Interation 4 Finished
# SerpAPI Search Interation 5 Finished

# %%
type(flat_results[0])
# Out:
# dict

# %%
flat_results[1]
# Out:
# {'position': 2,
#  'title': 'Job Application for AI Engineer at CoreStory',
#  'link': 'http://job-boards.greenhouse.io/corestory/jobs/4984207007',
#  'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=http://job-boards.greenhouse.io/corestory/jobs/4984207007&ved=2ahUKEwioyInl4tWTAxXXKlkFHaR8HGoQFnoECBsQAQ',
#  'displayed_link': 'http://job-boards.greenhouse.io › corestory › jobs',
#  'favicon': 'https://serpapi.com/searches/69d1d7543c99ba976969bab8/images/b5bYFbVtRlgh9a3-KgRIk6SAYRAEZP30_5FkR-AxbxI.png',
#  'snippet': "You'll work across LLM integration, vector search systems, prompt orchestration, agentic systems, and retrieval-augmented generation (RAG) pipelines. You'll ...",
#  'snippet_highlighted_words': ['agentic systems',
#   'retrieval-augmented',
#   'RAG'],
#  'about_this_result': {'source': {'description': "You'll work across LLM integration, vector search systems, prompt orchestration, agentic systems, and retrieval-augmented generation (RAG) pipelines. You'll ...",
#    'source_info_link': 'http://job-boards.greenhouse.io/corestory/jobs/4984207007',
#    'icon': 'https://serpapi.com/searches/69d1d7543c99ba976969bab8/images/b5bYFbVtRlgh9a3-KgRIkzhIVsiDIKd9V1ooznXGKTsYEvHewaQ1CGZ2WPTO4FLl.png'},
#   'languages': ['en'],
#   'regions': ['US']},
#  'about_page_link': 'https://www.google.com/search?q=About+http://job-boards.greenhouse.io/corestory/jobs/4984207007&tbm=ilp',
#  'about_page_serpapi_link': 'https://serpapi.com/search.json?engine=google_about_this_result&google_domain=google.com&q=About+http%3A%2F%2Fjob-boards.greenhouse.io%2Fcorestory%2Fjobs%2F4984207007',
#  'source': 'Greenhouse',
#  'searched_via': 'serp'}

# %%
len(flat_results)
# Out:
# 40

# %%
flat_results[0]["searched_via"]
# Out:
# 'serp'

# %% [markdown]
# # Exa Web Search

# %%
from exa_py import Exa

# %%
EXA_API_KEY = os.getenv("EXA_API_KEY")

if not EXA_API_KEY:
    raise ValueError("Exa API key not found in env variables.")

# %%
exa_client = Exa(api_key=EXA_API_KEY)

# %%
results = exa_client.search(
    query="remote ai engineer",
    type="auto",
    contents={"highlights": {"max_characters": 4000}},
    exclude_text=["senior"]
)

print(results)
# Out:
# Title: Remote Artificial Intelligence Engineer (AI) Jobs in 2026 - Wellfound
# URL: https://wellfound.com/role/r/artificial-intelligence-engineer
# ID: https://wellfound.com/role/r/artificial-intelligence-engineer
# Score: None
# Published Date: None
# Author: None
# Image: https://assets.wellfound.com/locations/hero-jobs.png
# Favicon: https://wellfound.com/wellfound-favicon-32x.png
# Extras: None
# Subpages: None
# Text: None
# Summary: None
# Highlights: ['Remote Artificial Intelligence Engineer (AI) Jobs in 2026 | Wellfound\n\nArtificial Intelligence Engineer (AI)\n\nRemote Search\n\n# Remote Artificial Intelligence Engineer (AI) Jobs\n\n#### Page 1 of 110\n\n#### 7553 results total ## MedOne Systems\n\nActively Hiring   ...    Based on past data, MedOne Systems usually responds to incoming applications within two weeks Applied Artificial Intelligence Engineer Full-time\n\n$140k – $200k • 0.0% – 1.0% Remote only • United States\n\n4 years of exp\n\n2 weeks ago\n\n2 weeks agoSave\n\nApply\n\n## Affinity.co\n\nActively Hiring   ...    Solutions Engineer Full-time\n\n$141k – $176k\n\n1 week ago\n\n1 week agoSave\n\nApply Senior AI Engineer, AI Platform Full-time\n\n$160k – $220k CAD\n\n2 weeks ago\n\n2 weeks agoSave\n\nApply   ...    Apply\n\n## GF-ACCORD AI\n\nActively Hiring\n\nAI replacing Business Analysts, Marketers, Consultants1-10 Employees   ...    1.0% – 2.0%\n\nOnsite or remote • Geneva+ 1\n\n8 years of exp\n\n1 week ago\n\n1 week agoSave\n\nApply CTO and Head of IT (AI) Full-time\n\n1.0% – 4.0%\n\nOnsite or remote • Geneva+ 8\n\n8 years of exp\n\n1 week ago 1 week agoSave\n\nApply\n\nAI software engineer Full-time\n\n1.0% – 2.0%\n\nOnsite or remote • Geneva+ 6   ...    Instant Access to Critical Construction Insights1-10 Employees\n\nAI Engineer (Full-Stack AI) Full-time $60k – $100k • 0.1% – 0.5%\n\nOnsite or remote • Oslo+ 1\n\n3 years of exp\n\n2 weeks ago\n\n2 weeks agoSave\n\nApply   ...    Senior AI Engineer Full-time\n\n$190k – $235k\n\n1 week ago\n\n1 week agoSave\n\nApply Staff AI Engineer Full-time\n\n$190k – $235k\n\n1 week ago\n\n1 week agoSave\n\nApply   ...    Founding AI Engineer Full-time\n\n$125k – $175k • 1.0% – 2.0%\n\nOnsite or remote • New York City+ 1   ...    Vontive is the first embedded mortgage platform for investment real estate51-200 Employees\n\nB2B\n\nGrowth Stage   ...    6 years of exp\n\n2 weeks ago\n\n2 weeks agoSave\n\nApply\n\nAI Engineer Full-time\n\n$120k – $160k • 0.0% – 0.1%   ...    Rapidly increasing operations\n\n- + 2\n\nAI Engineer (Intern) Full-time\n\nRemote • United States\n\n3 days ago   ...    Invoca is the leader in conversation intelligence for revenue teams at B2C brands201-500 Employees\n\n4.3\n\nHighly rated   ...    We deliver AI solutions for energy, real estate, supply chain and other infrastructure industries11-50 Employees   ...    Founding AI Engineer Full-time\n\n$140k – $200k • 0.0% – 2.0%\n\nRemote only • Canada+ 1\n\n5 years of exp   ...    Super is the AI assistant for property management1-10 Employees\n\nResponds within three weeks   ...    AI Agent Implementation Specialist Full-time\n\n$20k – $24k • 0.1% – 0.15%\n\nRemote only • Everywhere   ...    3 months agoSave\n\nApply\n\n## Explore other job opportunities\n\n### Explore other remote roles ETL Developer Remote Full Stack Developer Remote PPC Marketing Remote [Chief   ...    Brand Director Remote SaaS Developer Remote UI/UX Designer Remote Crypto Sales Remote VR Designer Remote Information Security Project Manager Remote ETL Testing Remote Network Security Engineer Remote QA Engineer Remote ### Explore Artificial Intelligence Engineer (AI) jobs in other places Artificial Intelligence Engineer (AI) - San Francisco Artificial Intelligence Engineer (AI) - Los Angeles Artificial Intelligence Engineer (AI) - Boston Artificial Intelligence Engineer (AI) - Chicago Artificial Intelligence Engineer (AI) - Seattle [Artificial Intelligence Engineer (AI) -   ...    - Remote First Future Jobs\n- Jobs for Bootcamp Grads   ...    - Startup Jobs in Bay Area\n- Top Women-Led Startups\n- More Featured Lists Remote Jobs - Remote Software Engineer Jobs\n- Remote Product Manager Jobs - Remote Data Analyst Jobs\n- Remote Product Designer Jobs - Remote Graphic Designer Jobs\n- Remote UI/UX Designer Jobs - Remote Operations Manager Jobs\n- Remote Growth Marketer Jobs - Remote Account Manager Jobs\n- Remote Sales Manager Jobs - Remote Financial Analyst Jobs\n ...
# Highlight Scores: [0.267578125]
#
#
# Title: Artificial Intelligence Engineer jobs in Remote - Indeed
# URL: https://www.indeed.com/q-artificial-intelligence-engineer-l-remote-jobs.html
# ID: https://www.indeed.com/q-artificial-intelligence-engineer-l-remote-jobs.html
# Score: None
# Published Date: None
# Author: None
# Image: https://d2q79iu7y748jz.cloudfront.net/s/_squarelogo/256x256/238acc37ec1092cece6055b9e71f0edb
# Favicon: https://www.indeed.com/images/favicon.ico
# Extras: None
# Subpages: None
# Text: None
# Summary: None
# Highlights: ['Flexible Artificial Intelligence Engineer Jobs – Apply Today to Work From Home in Remote (April 6, 2026) | Indeed Skip to main content\n\n \n\n \n\n \n\nKeyword : all jobs\n\n\xa0\n\nEdit location input box label\n\nSearch\n\nPay\n\nRemote Job Type\n\nExperience level\n\nResidency Requirement\n\nEducation\n\nEncouraged to apply\n\nDate posted Upload your resume- Let employers find you\n\n\xa0\n\n# artificial intelligence engineer jobs in Remote Sort by: -\n\n \n\n \n\n## Agentic AI Agent Engineer & Architect\n\nEasily apply\n\nNew\n\nFull Service Pros\n\nRemote\n\nFull-time   ...    - This is a high-impact, executive-level position where you will design and build autonomous AI agents that support and   ...    ## CCaaS Implementation Engineer, AI.bot focus\n\nEasily apply\n\nTechnical Source\n\nRemote in Raleigh, NC 27607   ...    ## Chief Engineer – Artificial Intelligence (AI) Applications\n\nGeneral Dynamics Mission Systems, Inc\n\nHybrid work   ...    ## Software Engineer, Machine Learning\n\nMeta\n\nRemote\n\n$88.46 an hour   ...    - View all Meta jobs in Remote- Remote jobs- [Machine Learning Engineer jobs in   ...    ## AI Context Engineer\n\nCACI\n\nRemote\n\n$98,500 - $206,800 a year\n\nFull-time\n\nHealth insurance - Contribute as a core engineer on modernization efforts.\n- Minimum Clearance Required to Start: Secret.   ...    - View all CACI jobs in Remote- Remote jobs- AI Developer jobs in Remote   ...    Go to beginning of carousel\n\n \n\n## Senior AI Full Stack Engineer\n\nEasily apply\n\nAmeriSave Mortgage Corp.\n\nRemote $150,000 - $200,000 a year\n\nPaid training\n\nReferral program\n\n401(k)\n\nHealth insurance\n\nPaid time off   ...    - Collaborate with AI/ML engineers and data scientists to embed intelligent automation and decisioning into enterprise   ...    ## AI/ML Developer :: Remote :: 8+ Years :: Only Local to PA\n\nEasily apply\n\nSoftware Technology Inc   ...    - AI Machine Learning (ML) development, preferably in retail or customer service environments.   ...    - View all Software Technology Inc jobs in Harrisburg, PA- Harrisburg jobs- [AI Developer jobs   ...    ## Sr Engineer - AI Experiences\n\nLenovo\n\nRemote in Chicago, IL\n\n$190,000 - $210,000 a year\n\nFull-time   ...    ## Release Engineer\n\nVeeva Systems\n\nRemote\n\n$55,000 - $110,000 a year\n\nFull-time\n\nHealth insurance\n\nPaid time off   ...    Go to beginning of carousel\n\n \n\n## Software Engineer - Full Stack\n\nVeeva Systems\n\nRemote\n\n$85,000 - $225,000 a year   ...    ## Agentic AI\n\nIntone Networks\n\nRemote\n\nContract - This is a hands-on engineering role focused on delivering scalable, secure, and reliable AI-driven solutions in a   ...    - View all Intone Networks jobs in Remote- Remote jobs- Agent jobs in Remote   ...    - 5-10+ years as a software/data/ML engineer.\n- Strong Python expertise and familiarity with modern data/ML tooling. - View all Intone Networks jobs in Remote- Remote jobs- [AI/ML Engineer jobs in   ...    ## AI Engineer\n\nIntone Networks\n\nRemote\n\nContract - 5+ years experience in machine learning, deep learning, and data science.\n- Proficiency in Python and ML libraries. - View all Intone Networks jobs in Remote- Remote jobs- AI Developer jobs in Remote   ...    ## AI Engineer\n\nIntone Networks\n\nRemote\n\nContract\n\nView similar jobs with this employer   ...    - See popular questions & answers about Los Alamos National Laboratory Get email updates for the latest artificial intelligence engineer jobs in remote   ...    ## Job Post Details\n\n## Agentic AI Agent Engineer & Architect - job post\n\nFull Service Pros\n\nRemote Full-time\n\n \n\n## Profile insights\n\nFind out how your skills align with the job description\n\n### Skills   ...    Full Service Pros is a rapidly growing restoration company specializing in fire, water, and mold remediation. When   ...    We are now expanding into advanced automation and AI systems to scale operations across multiple business  ...
# Highlight Scores: [0.31640625]
#
#
# Title: Remote AI Engineer Jobs – Apply Now | RemoteRocketship.com
# URL: https://www.remoterocketship.com/us/jobs/ai-engineer/
# ID: https://www.remoterocketship.com/us/jobs/ai-engineer/
# Score: None
# Published Date: None
# Author: None
# Image: https://www.remoterocketship.com/remoterocketship.jpg
# Favicon: https://www.remoterocketship.com/favicon-32x32.png
# Extras: None
# Subpages: None
# Text: None
# Summary: None
# Highlights: ["Remote AI Engineer Jobs – Apply Now | RemoteRocketship.com\n\n# Remote AI Engineer Jobs ## Search 276 work from home ai engineer positions. Your career in truly remote companies - apply today. Loved by 10,000+ remote workers\n\nFind Your Dream Remote Job\n\nReceive Emails For Remote Jobs\n\n🤖 AI Engineer 🇺🇸 United States – Remote USA\n\n💵 Minimum Salary\n\n⚪️ Experience\n\nShow all filters Remote only jobs Hybrid jobs Onsite jobs\n\nHelp me find beginner remote jobs\n\n### People also searched for: ai research scientist jobs machine learning engineer jobs\n\n276 total jobs\n\n🆕 Date Added 37 new jobs this week ⚡️\n\n57% are NOT on LinkedIn 🚫\n\n### AI Engineer III\n\n🔥 11 hours ago\n\n🔥 11 hours ago #### Premera Blue Cross\n\n1001 - 5000\n\n⚕️ Healthcare Insurance   ...    AI Engineer III developing AI/ML solutions and prototypes for complex healthcare problems at Premera. Collaborating   ...    [🐻 Alaska, Arizona, +25 more states – Remote🐻 Alaska – Remote 🌵 Arizona – Remote 🏄 California – Remote ⛰️ Colorado –   ...    💵 $118.9k - $202.1k / year\n\n⏰ Full Time\n\n🟡 Mid-level\n\n🟠 Senior\n\n🤖 AI Engineer   ...    ### AI Engineer – Go-To-Market\n\nJob not on LinkedIn\n\n🔥 16 hours ago\n\n🔥 16 hours ago\n\nJob not on LinkedIn   ...    AI Engineer improving productivity in GTM operations at dbt Labs through AI-enhanced capabilities and workflow   ...    Senior AI Engineer developing AI tools for researchers and publishers. Leveraging large language models and machine   ...    Senior AI Engineer architecting production-grade AI solutions for WEX, a global commerce platform. Collaborate with   ...    Senior AI Engineer designed to own the production delivery of AI systems at RegScale. Focused on building and operating   ...    AI Engineer developing advanced AI solutions including LLMs for clinical and operational challenges. Collaborating with   ...    🤖 AI Engineer\n\n🦅 H1B Visa Sponsor\n\n+257 More AI Engineer Jobs Available!\n\nSign Up Loved by 10,000+ remote workers\n\n## Top Companies Hiring Remote AI Engineers\n\n### Abbott\n\n#### Job Openings - AI Engineer\n- AI Engineer\n\n### Beyondsoft\n\n#### Job Openings\n\n- AI Engineer   ...    ### General Dynamics Information Technology\n\n#### Job Openings\n\n- AI Engineer – Architect ## Remote ai engineer salary expectations The average salary for remote ai engineers is $169,171 per year. This is based on data from 1,115 job openings. Our advanced AI searches the internet for remote job openings and posts them on our website. We use the salary data from   ...    Below is a breakdown of salary data by years of experience:\n\n⚪️ Entry-level AI Engineer (0 yrs) | Experience | Number of roles analyzed | Average Salary |\n| --- | --- | --- |\n| 30 | $67,705 |   ...    | 🟡 Mid-level AI Engineer (2-4 yrs) | 407 | $155,891 |   ...    We analyzed 783 job listings in the last year and found it takes about 49 days for employers to close a job opening.   ...    We reviewed 1,115 job postings and found the top 10 skills employers are asking for most often are:\n\nPython71.8% Machine learning45.8%\n\nAi31.7%\n\nAws22.2%\n\nPytorch18.3%\n\nTensorflow17.8%\n\nMlops15.4%\n\nApis14.5%\n\nSql13.1% Kubernetes11.8%\n\n### Join now to find your dream remote job\n\n#### Discover hidden jobs We scan the internet everyday and find jobs not posted on LinkedIn or other job boards.   ...    Most members hear back within the first week\n\n#### 10,000+ more jobs than other job boards   ...    What is the difference between Remote Rocketship and other job boards?\n\nWe find jobs other job boards miss.   ...    Who built Remote Rocketship? Remote Rocketship is a solo project by me, Lior Neu-ner. I built this website for my wife when she was looking for a   ...    Developed by Lior Neu-ner. I'd love to hear your feedback — Get in touch via DM or support@remoterocketship.com Search Remote Jobs Search Remote Jobs by Job Title Search Remote Jobs by Tech Stack Search jobs by state Search H1B visa jobs S ...
# Highlight Scores: [0.30859375]
#
#
# Title: Best Remote AI Engineer Jobs 2026 | Built In
# URL: https://builtin.com/jobs/remote/dev-engineering/search/artificial-intelligence-engineer
# ID: https://builtin.com/jobs/remote/dev-engineering/search/artificial-intelligence-engineer
# Score: None
# Published Date: None
# Author: None
# Image: https://static.builtin.com/dist/images/bi-header-logo.svg
# Favicon: https://static.builtin.com/dist/images/favicon.png
# Extras: None
# Subpages: None
# Text: None
# Summary: None
# Highlights: ['Best Remote AI Engineer Jobs 2026 | Built In\n\nGet the job you really want.   ...    @blur="onJobSearchBlur()" @focus="getJobTitles()" id="searchJobsInput" x-ref="searchJobsInput" type="text" aria-describedby="search" placeholder="Job Title, Company or Keyword"> Job Title, Company or Keyword 0" type="button" style="right:3rem;">\n\nRemote / Hybrid\n\nClear\n\nLocation\n\nNew Jobs\n\nClear\n\nJob Category\n\nClear   ...    aria-expanded="false"> All Filters Reset Save Job Alert Save Alert\n\nMaximum of 25 job preferences reached.\n\n# Top Remote AI Engineer Jobs\n\nRapid7 ## Principal AI Engineer\n\nReposted YesterdaySaved\n\nRemote or Hybrid\n\nBelfast, County Antrim, Northern Ireland, GBR Expert/Leader\n\nExpert/Leader Artificial Intelligence • Cloud • Information Technology • Sales • Security • Software • Cybersecurity The Principal AI Engineer will design and implement AI models and systems, mentor team members, and ensure AI solutions   ...    Top Skills: Aws BedrockCrewaiHuggingfaceKerasNumpyPandasPythonPyTorchSagemakerScikit-LearnTensorFlowTransformers Rapid7\n\n## Staff AI Engineer\n\nReposted 14 Days AgoSaved\n\nRemote or Hybrid Belfast, County Antrim, Northern Ireland, GBR\n\nSenior level\n\nSenior level   ...    As a Staff AI Engineer, you\'ll design ML production systems, manage data pipelines, ensure data quality, and enhance AI   ...    Top Skills: AWSBedrockDockerEksFastapiFlaskJupyter NotebooksKubernetesNumpyPandasPythonSagemakerSci-Kit LearnTerraform Mistral AI\n\n## Applied AI Engineer, Senior/Staff Devops/SRE - EMEA\n\nReposted YesterdaySaved In-Office or Remote\n\n5 Locations\n\nJunior\n\nJunior\n\nArtificial Intelligence The Applied AI Engineer will onboard customers, deploy AI applications, and collaborate with teams to resolve technical   ...    Top Skills: AnsibleAWSAzureCi/CdDockerGCPKubernetesPythonPyTorchTensorFlowTerraform\n\nSamsara ## Staff Software Engineer - Safety AI\n\nReposted 5 Days AgoSaved\n\nEasy Apply\n\nRemote or Hybrid\n\nUK\n\nEasy Apply   ...    Samsara seeks a Staff Software Engineer to lead technical design and architecture on the Fleet Safety team, improving   ...    Top Skills: C/C++GoJavaScriptPythonTypescript\n\nKainos\n\n## Lead AI Engineer\n\nReposted YesterdaySaved In-Office or Remote\n\n6 Locations\n\nSenior level\n\nSenior level\n\nInformation Technology As a Lead AI Engineer, you\'ll bridge data science and software engineering, focusing on productionizing AI solutions,   ...    Top Skills: AWSAzureAzure Ml StudioC++DockerGCPJavaKubernetesPythonSagemakerVertex Ai\n\nCytora ## AI Engineer\n\nReposted YesterdaySaved\n\nRemote\n\n2 Locations\n\nMid level\n\nMid level Artificial Intelligence • Insurance • Software • Business Intelligence As an AI Engineer, you will develop and optimize Large Language Model services, focusing on risk processing in   ...    Top Skills: AsyncioMypyPython\n\nDataCamp\n\n## Staff AI Engineer - AI Creator\n\n3 Days AgoSaved\n\nEasy Apply Remote\n\n5 Locations\n\nEasy Apply\n\nMid level\n\nMid level\n\nEdtech   ...    Top Skills: Llm (Large Language Models)Python\n\nNew\n\n## Track Smarter, Apply Better.   ...    As a Principal AI Engineer, you\'ll build and evolve AI tutoring systems, run experiments for learning effectiveness,   ...    Top Skills: AILlmMachine LearningPython\n\nDATAPAO\n\n## Senior AI Engineer (Databricks) - UK Reposted 4 Days AgoSaved\n\nEasy Apply\n\nRemote\n\nUnited Kingdom\n\nEasy Apply\n\n70K-100K Annually\n\nSenior level   ...    As a Senior AI Engineer at DATAPAO, you will lead AI projects, provide ML consultancy, and act as a client interface,   ...    Responsible for designing and developing AI products, collaborating with cross-functional teams, and advancing AI   ...    As an AI Engineer, you will design and implement the Auto-Moderation Service and AI features, working with Full Stack   ...    Cohere AI\n\n## Applied AI Engineer – Agentic Workflows\n\nReposted 5 Days AgoSaved\n\nIn-Office or Remote 5 Loca ...
# Highlight Scores: [0.267578125]
#
#
# Title: Remote AI engineer jobs - Turing
# URL: https://www.turing.com/jobs/remote-ai-jobs
# ID: https://www.turing.com/jobs/remote-ai-jobs
# Score: None
# Published Date: None
# Author: None
# Image: https://www.turing.com/img/og_image.webp
# Favicon: None
# Extras: None
# Subpages: None
# Text: None
# Summary: None
# Highlights: ["Remote AI engineer jobs | Turing jobs\n\n# Remote AI engineer jobs At Turing, we are looking for experienced AI engineers to work with top U.S companies. If you have the required expertise in building AI models and production infrastructure, join Turing today and accelerate your career while   ...    Apply as AI engineer\n\n## Find remote software jobs with hundreds of Turing clients\n\n## Job description   ...    - Set up and run machine learning systems and AI infrastructure to automate predictive models   ...    ### Minimum requirements - Bachelor’s/Master’s degree in Computer Science, Data Engineering, Mathematics, IT, or relevant field - 3+ years of experience as an AI or ML Engineer working on enterprise products (rare exceptions for super efficient   ...    ### Interested in this job?\n\nApply to Turing today.\n\nApply now\n\n## Why join Turing?Watch Video ### 1Elite US Jobs\n\nTuring’s developers earn better than market pay in most countries, working with top US companies.   ...    Read Turing.com reviews from developers across the world and learn what it’s like working with top U.S. companies. 4.65OUT OF 5\n\nbased on developer reviews as of June 2024\n\nView all reviews Chinonso, NigeriaSoftware Developer I had a hazy picture of my future in my mind, and Turing is making it clearer and   ...    Feyzullah, TurkeySoftware EngineerBefore Turing, I had never tried remote work. Now, I want to retire remotely. Mugisha, RwandaData EngineerRemote work exposes you to opportunities that won’t be possible if you work locally. ## Find out why developers love Turing\n\nSee all Turing reviews\n\nView all reviews ## How to become a Turing developer?\n\nWork with the best software companies in just 4 easy steps ### Create your profile\n\nFill in your basic details - Name, location, skills, salary, & experience. ### Take our tests and interviews\n\nSolve questions and appear for technical interview.\n\n### Receive job offers Get matched with the best US and Silicon Valley companies.\n\n### Start working on your dream job Once you join Turing, you’ll never have to apply for another job.\n\nApply now ### Learn how to create a perfect resume Turing.com lists out the do’s and don’ts behind a great resumeto help you find a top remote AI jobs. Learn more\n\n## How to become an AI engineer ? Artificial Intelligence is one of the most exciting technological advances we've ever witnessed. It has become an   ...    All of this means that the demand for remote AI engineer jobs is increasing rapidly. If you want to work as an AI   ...    To make a career in the AI development field, there are a few steps you need to follow. There is no requirement for   ...    ### Interested in remote AI engineer jobs?\n\nBecome a Turing developer!\n\nApply now   ...    one should understand deep learning algorithms and how to implement them using a framework.  ### Interested in remote AI engineer jobs? Become a Turing developer!\n\nApply now ### How to get remote AI engineer jobs?  Engineers are a lot like athletes. To excel at their craft, they have to   ...    signs of burnout!  Turing offers the best remote AI engineer jobs that suit your career trajectories as an AI engineer. Grow rapidly by working on challenging technical and business problems on the latest technologies. Join a network of the world's best engineers & get full-time, long-term remote AI engineer jobs with better compensation and career   ...    ### Why become an AI engineer at Turing? ##### Elite US jobs  Long-term opportunities to work for amazing, mission-driven US companies with great compensation.   ...    What is Turing?  Turing is an AGI infrastructure company specializing in post-training large language models (LLMs) to   ...    We, at Turing, hire remote developers for over 100 skills like React/Node, Python, Angular, Swift, React Native,   ...    ## Explore remote developer jobs\n\n##### Fullstack Engineer (India) Fullstack Engineer (India | 7–10 yrs)  - Bachelor’s/Ma ...
# Highlight Scores: [0.33984375]
#
#
# Title: 3,807 artificial intelligence engineer Jobs in Remote, April 2026
# URL: https://www.glassdoor.com/Job/remote-artificial-intelligence-engineer-jobs-SRCH_IL.0,6_IS11047_KO7,39.htm
# ID: https://www.glassdoor.com/Job/remote-artificial-intelligence-engineer-jobs-SRCH_IL.0,6_IS11047_KO7,39.htm
# Score: None
# Published Date: None
# Author: None
# Image: https://www.glassdoor.com/assets/images/meta/logo-og.png
# Favicon: https://www.glassdoor.com/favicon.ico
# Extras: None
# Subpages: None
# Text: None
# Summary: None
# Highlights: ["2,146 artificial intelligence engineer Jobs in Remote, June 2025 | GlassdoorSkip to main content Skip to contentSkip to footer\n\n* Community\n* Jobs   ...    Enjoy a breather.\nSign In\nartificial intelligence engineer, Remote\nSearch\nSearch Location\nSearch\nUpload your resume - let employers find you\nEasy Apply onlyRemote only\nSalary range \nCompany rating\nDate posted\n# 2,146 Artificial intelligence engineer jobs in Remote\nMost relevant * DataAnnotation Logo\nDataAnnotation\n4.0\nPlatform Development Engineer - AI Trainer United States\n$40.00Per Hour(Employer provided) You can work on your own schedule. A bachelor's degree (completed or in progress). You will work with the chatbots that   ...    Oceans Code Experts\n4.8\nArtificial Intelligence Engineer BS-01\nUnited States Bachelor's degree in Computer Science, Engineering, or a related field. Advanced degree in Computer Science,   ...    You can work on your own schedule. You will measure the progress of these AI chatbots, evaluate their logic, and solve   ...    **Skills:**Go, CSS, React, Writing skills, C#\n\n9d\n* DataAnnotation Logo\nDataAnnotation\n4.0 AI/ML Engineer\nHerndon, VA\n$40.00Per Hour(Employer provided) You can work on your own schedule. A bachelor's degree (completed or in progress). You will work with the chatbots that   ...    **Skills:**Go, CSS, React, Writing skills, C#\n\n30d+\n* Rightway Logo\nRightway\n3.0 Business Intelligence Engineer II\nRemote\n$100K - $125K(Employer provided) Work with data analysts and analytics engineers to design, develop, and maintain data models across multiple domains,   ...    Discover more\n4d\n* bi engineer jobs in RemoteRemote jobsRightway jobs in Remote   ...    * DataAnnotation Logo\nDataAnnotation\n4.0\nMachine Learning Engineer - AI Trainer\nNorfolk, VA   ...    **Skills:**Go, CSS, React, Writing skills, C#\n\n9d\n* DataAnnotation Logo\nDataAnnotation\n4.0 AI/ML Engineer\nVirginia\n$40.00Per Hour(Employer provided)   ...    **Skills:**Go, CSS, React, Writing skills, C#\n\n30d+\n* Fabric Labs, Inc. Staff Engineer, AI (Artificial Intelligence)\nRemote\nEasy Apply Collaborate with engineering to develop APIs for LLM applications used by other product components. Experience with   ...    **Skills:**Microsoft Excel, Kubernetes, Databases, AWS, Machine learning\n\nDiscover more\n14d   ...    * Agile Fuel Logo\nAgile Fuel\n4.8\nAI/ML Engineer\nRemote In this role, you will work closely with cross-functional teams to develop and productionize machine learning models,   ...    The Lead Engineer, Artificial Intelligence role is a pivotal position responsible for driving the strategic vision and   ...    ]# Platform Development Engineer - AI Trainer\nApply on employer siteApply now\nUnited States ·$40.00Per Hour(Employer provided)\nApply on employer siteApply now We are looking for proficient programmers to join our team to train our AI chatbots to code. You will work with the   ...    successful candidates work between 5-20 hours per week, up to 40 hours. Benefits:\n* This is a full-time or part-time REMOTE position * You’ll be able to choose which projects you want to work on\n* You can work on your own schedule   ...    * Evaluate code quality produced by AI models for correctness and performance\nQualifications:\n* Fluency in English   ...    Note: Payment is made via PayPal. We will never ask for any money from you.\n#INDUSSD\nJob Type: Contract Pay: From $40.00 per hour\nExpected hours: 1 –40 per week\nWork Location: Remote\n"]
# Highlight Scores: [0.337890625]
#
#
# Title: Remote AI Engineer Jobs - Crossover
# URL: https://www.crossover.com/jobs/ai-engineer
# ID: https://www.crossover.com/jobs/ai-engineer
# Score: None
# Published Date: None
# Author: None
# Image: None
# Favicon: https://www.crossover.com/assets/img/favicon.ico
# Extras: None
# Subpages: None
# Text: None
# Summary: None
# Highlights: ['Crossover \n\nCrossover']
# Highlight Scores: [0.18359375]
#
#
# Title: Remote Ai Jobs jobs in United States - LinkedIn
# URL: https://www.linkedin.com/jobs/remote-ai-jobs-jobs
# ID: https://www.linkedin.com/jobs/remote-ai-jobs-jobs
# Score: None
# Published Date: None
# Author: None
# Image: None
# Favicon: https://static.licdn.com/aero-v1/sc/h/al2o9zrvru7aqj8e1x2rzsrca
# Extras: None
# Subpages: None
# Text: None
# Summary: None
# Highlights: ['84,000+ Remote Ai Jobs jobs in United States \n\nAny time\n\n \n\nAny time (84,483)\n\nPast month (75,269)\n\nPast week (34,384) Past 24 hours (6,538)\n\nDone\n\n \n\nCompany \n\n` `` `` `\n\n \n\nYO IT Consulting (722)\n\nLensa (175)\n\nToloka Annotators (46) TSMG Holding (27)\n\nFarsight (11)\n\nDone\n\n \n\nJob type \n\n \n\nFull-time (72,183)\n\nPart-time (3,722)\n\nContract (5,454)   ...    $40,000+ (3,480)\n\n$60,000+ (3,414)\n\n$80,000+ (3,201)\n\n$100,000+ (2,970)\n\n$120,000+ (2,680)\n\nDone\n\n \n\nRemote Remote (59,639)\n\nOn-site (16,929)\n\nHybrid (9,556)\n\nDone\n\n \n\n \n\n \n\n \n\nGet notified when a new job is posted.\n\nSet alert # 84,000+ Remote Ai Jobs Jobs in United States\n\n### AI/Machine Learning Engineer\n\n#### CARTOL   ...    #### TSMG Holding\n\n \n\nMiami, FL\n\nBe an early applicant \n\n20 hours ago \n\n \n\n### Junior AI/ML Engineer (Remote) #### Lensa\n\n \n\nBoston, MA\n\nBe an early applicant \n\n12 hours ago \n\n \n\n### Clinical Data Scientists\n\n#### CIMS Global Somerset, NJ 20 hours ago \n\n \n\n### AI/ML Engineer\n\n#### Farsight\n\n \n\nNew York, NY 1 week ago   ...    New York, United States\n\nBe an early applicant \n\n6 days ago \n\n \n\n### Artificial Intelligence Engineer\n\n#### GENISYSAPP   ...    Be an early applicant \n\n2 days ago \n\n \n\n### AI/ML Engineer Internship\n\n#### Bowler Pons Solutions Consultants, LLC Annapolis, MD\n\nBe an early applicant \n\n1 week ago \n\n \n\n### Ai Trainer/Data Annotator - Remote\n\n#### YO IT Consulting   ...    #### Crossing Hurdles\n\n \n\nUnited States 1 week ago \n\n \n\n### AI/ML Engineer - Remote\n\n#### YO IT Consulting San Francisco, CA\n\nBe an early applicant \n\n12 hours ago \n\n \n\n### Ai Trainer/Data Annotator - Remote   ...    Be an early applicant \n\n20 hours ago \n\n \n\n### AI/ML Data Contributor\n\n#### TSMG Holding\n\n \n\nIndianapolis, IN Be an early applicant \n\n20 hours ago \n\n \n\n### AI Engineer\n\n#### eimagine\n\n \n\nIndianapolis, IN\n\nBe an early applicant 9 hours ago \n\n \n\n### AI Tech Analyst Intern\n\n#### Precisely\n\n \n\nUnited States 7 hours ago ### AI/ML Engineer - Remote\n\n#### YO IT Consulting\n\n \n\nAustin, CO 2 days ago \n\n \n\n### Data Scientist   ...    ### AI/ML Engineer - Remote\n\n#### YO IT Consulting\n\n \n\nSan Jose, CA\n\nBe an early applicant \n\n12 hours ago   ...    2 days ago \n\n \n\n### Data Science Intern (Summer 2026)\n\n#### Hone Health\n\n \n\nNew York, NY 3 days ago ### AI/ML Engineer - Remote\n\n#### YO IT Consulting\n\n \n\nUnited States\n\nBe an']
# Highlight Scores: [0.29296875]
#
#
# Title: Best Remote Artificial Intelligence Engineer Jobs in Denver ...
# URL: https://www.builtincolorado.com/jobs/remote/dev-engineering/search/artificial-intelligence-engineer
# ID: https://www.builtincolorado.com/jobs/remote/dev-engineering/search/artificial-intelligence-engineer
# Score: None
# Published Date: None
# Author: None
# Image: None
# Favicon: https://static.builtin.com/dist/images/favicon.png
# Extras: None
# Subpages: None
# Text: None
# Summary: None
# Highlights: ['Best Remote Artificial Intelligence Engineer Jobs in Denver & Boulder, CO 2026 | Built In Colorado Get the job you really want.\n\nRemote / Hybrid\n\nClear\n\nLocation\n\nNew Jobs\n\nClear\n\nJob Category\n\nClear\n\n0}" Industry   ...    Save Job Alert Save Alert\n\nMaximum of 25 job preferences reached. # Top Remote Artificial Intelligence Engineer Jobs in Denver & Boulder, CO\n\nHiya Inc.\n\n## AI Engineer Reposted YesterdaySaved\n\nRemote or Hybrid\n\n4 Locations\n\n134K-262K Annually\n\nMid level\n\n134K-262K Annually\n\nMid level Artificial Intelligence • Cloud • Mobile • Security • Software As an AI Engineer, you\'ll integrate AI solutions, optimize models, collaborate on technical solutions, and shape the technical direction at Hiya. Top Skills: AutogenAWSAzureGCPJavaScriptKubernetesLangchainN8NPythonTypescript\n\nHiya Inc.\n\n## AI Engineer Reposted YesterdaySaved\n\nRemote or Hybrid\n\n4 Locations\n\n134K-262K Annually\n\nMid level\n\n134K-262K Annually\n\nMid level   ...    AI Engineers at Hiya develop and integrate AI solutions, conduct model evaluations, and optimize large language models,   ...    Top Skills: AutogenAWSAzureGCPJavaScriptKubernetesLangchainN8NPythonTypescript\n\nHex ## AI Engineer, Search and Context\n\nReposted 2 Days AgoSaved\n\nRemote or Hybrid\n\n3 Locations\n\n225K-275K Annually   ...    AI Engineers at Hex will build AI experiences, manage search and context architecture, and work on scalable AI   ...    Top Skills: AIJavaScriptMlMlopsPythonTypescript\n\nZeta Global\n\n## Lead AI Engineer\n\n4 Days AgoSaved Easy Apply\n\nRemote or Hybrid\n\nUnited States\n\nEasy Apply\n\n200K-215K Annually\n\nSenior level\n\n200K-215K Annually   ...    Lead end-to-end post-training lifecycle for LLMs: curate SFT and preference datasets, run SFT and preference   ...    Rula\n\n## Principal AI Engineer (Remote)\n\nReposted 4 Days AgoSaved\n\nRemote\n\nUnited States 229K-284K Annually\n\nSenior level\n\n229K-284K Annually\n\nSenior level   ...    The Principal AI Engineer will lead the design and implementation of scalable AI systems in mental healthcare, ensuring   ...    Top Skills: AnthropicAWSBedrockDspyFaissGCPGeminiGoHaystackJavaJavaScriptLangchainLlamaindexMilvusOpenaiPineconePythonTypescriptWea   ...    BNSF Railway\n\n## Sr/Staff AI Engineer\n\nReposted 6 Days AgoSaved\n\nRemote\n\nUnited States\n\n160K-300K Annually Senior level\n\n160K-300K Annually\n\nSenior level\n\nTransportation The role involves designing, implementing, and optimizing AI models for railroad operations while ensuring integration   ...    Top Skills: AWSAws S3AzureDatabricksHadoopJavaJupyterlabPysparkPythonPyTorchRRdsScikit-LearnSparkTensorFlow Wasabi Technologies\n\n## Senior Enterprise AI Engineer\n\nReposted 9 Days AgoSaved\n\nEasy Apply\n\nRemote United States of America\n\nEasy Apply\n\n160K-200K Annually\n\nSenior level\n\n160K-200K Annually\n\nSenior level   ...    The role involves building and scaling the Enterprise AI Platform at Wasabi, designing AI-powered solutions,   ...    Reposted 10 Days AgoSaved\n\nRemote\n\n2 Locations\n\n192K-287K Annually\n\nSenior level\n\n192K-287K Annually\n\nSenior level   ...    Zapier seeks an Applied AI Engineer to develop AI-driven automation tools. Responsibilities include working with large   ...    Samsara\n\n## AI Engineer\n\nReposted 10 Days AgoSaved\n\nEasy Apply\n\nRemote or Hybrid\n\nUnited States   ...    As an AI Engineer, you will build and scale AI business applications, focusing on generative AI. Responsibilities   ...    Use ourAI Assistantto automatically fill your job applications.\n\nUse For Free   ...    Remote or Hybrid\n\n2 Locations\n\n120K-180K Annually\n\nMid level\n\n120K-180K Annually\n\nMid level   ...    We are seeking a Senior Software Engineer specializing in AI to enhance our Website Experience Platform.   ...    Reposted 5 Days AgoSaved\n\nEasy Apply\n\nRemote or Hybrid\n\nUnited States\n\nEasy Apply\n\n300K-400K Annually\n\nExpert/Leader    ...
# Highlight Scores: [0.271484375]
#
# Resolved Search Type: neural
# Search Time: 988.9ms
# CostDollars: total=0.007
#   - search: {'neural': 0.007}

# %% [markdown]
# Note: response.results holds 10 RESULTs

# %% [markdown]
# ## Handling Multiple Queries and Extracting value into Dictionary

# %%
all_exa_results = []

for i, q in enumerate(exa_queries):
    response = exa_client.search(
        query=q,
        type="auto",
        contents={"highlights": {"max_characters": 4000}},
        exclude_text=["senior"]
    )
    print(f"Exa Search Iteration {i + 1} Finished")
    
    all_exa_results.extend([
        {
            "title": result.title,
            "link": result.url,
            "text": result.highlights[0] if result.highlights else None,
            "searched_via": "exa"
        }
        for result in response.results
    ])
    time.sleep(1)
# Out:
# Exa Search Iteration 1 Finished
# Exa Search Iteration 2 Finished
# Exa Search Iteration 3 Finished
# Exa Search Iteration 4 Finished
# Exa Search Iteration 5 Finished

# %%
len(all_exa_results[49])
# Out:
# 4

# %%
all_exa_results[8]
# Out:
# {'title': 'Digital AI Development Engineer – Avion Solutions – Job Huntsville, AL',
#  'link': 'https://www.talent.com/view?id=605756631292521836',
#  'text': "Digital AI Development Engineer – Avion Solutions – Job Huntsville, AL\n\nFind jobs Digital AI Development EngineerAvion Solutions • Huntsville, Alabama, US\n\nJob description Avion Solutions Inc., an employee-owned company, is seeking candidates for a Digital AI Development Engineer to support the Missile Defense Agency (MDA). This position is located in Huntsville, AL. Job Responsibilities/Duties: Design and implement AI pipelines for data ingestion, processing, and model deployment using frameworks like LangChain and Open WebUI. Develop and manage embeddings databases to support semantic search, recommendation systems, and other AI-driven applications. Integrate AI solutions with cloud platforms such as Azure Foundry to ensure scalability, reliability, and security. Collaborate with cross-functional teams to identify requirements and deliver AI solutions tailored to business needs. Optimize AI workflows for performance and efficiency, ensuring seamless integration with existing systems. Stay updated on the latest advancements in AI tools, frameworks, and methodologies to continuously improve pipeline   ...    Other duties as assigned.\n\nRequired Experience: Bachelor's degree in Computer Science, Engineering, or a related STEM field.\n\n3+ years of related work experience. Working understanding of AI pipelines, including data processing, model deployment, and integration. Understanding of frameworks such as LangChain, Open WebUI, and embeddings databases. Strong programming skills in Python or similar languages, with a focus on AI and data processing libraries. Ability to work independently while collaborating effectively with team members. Excellent problem-solving skills and attention to detail. Must be a U.S. citizen and have an active DoD Secret Security Clearance. Must be able to travel up to 15% of the time.\n\nPreferred Qualifications: Experience with cloud platforms like AWS, Bedrock, SageMaker, or Azure Foundry for AI solution deployment. Familiarity with semantic search and recommendation systems. Knowledge of distributed systems and scalable architectures for AI pipelines. Experience with containerization tools like Docker and orchestration platforms like Kubernetes. Understanding of MLOps practices for continuous integration and deployment of AI models.   ...    Solid understanding of full-stack development principles, including front-end technologies (HTML, CSS, JavaScript, React, Angular, or Vue.js) and back-end technologies (Python, Node.js, Java, Go) with relevant frameworks (Django,   ...    Understanding of software architecture patterns, design principles, and security best practices for cloud environments   ...    Experience working in an Agile development environment and collaborating effectively with cross-functional teams.   ...    Equal Opportunity: Avion Solutions, Inc. reaffirms its belief in equal employment opportunity for all employees and applicants. Avion Solutions, Inc. is an Equal Employment Opportunity Employer and a VEVRAA-governed Federal Contractor that affords equal employment opportunity to protected veterans and people with disabilities. Avion Solutions, Inc. provides all employees and job applicants equal employment opportunities in hiring and promotion without regard to age,   ...    disability, national origin, or any other reason prohibited by law. ##### Create a job alert for this search\n\nDigital AI Development Engineer • Huntsville, Alabama, US\n\nCreate Similar jobs",
#  'searched_via': 'exa'}

# %% [markdown]
# ### What Properties to Extract:
# 1. title
# 2. link
# 3. text (JD)
# 5. searched_via
