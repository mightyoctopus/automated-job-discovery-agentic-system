# %% [markdown]
# # Internal Pre-Filter Logic
# This function is supposed to filter out the minimul noise before the data passing into the final LLM-driven evaluator function

# %%
from typing import Optional, List
from dataclasses import dataclass

@dataclass
class Job:
    title: str
    url: str
    text: Optional[str]
    searched_via: str

# %%
total_jobs = [
    Job(
        title='Job Application for Staff AI Engineer at Clarity AI', 
        url='https://boards.greenhouse.io/clarityai/jobs/4802689101', 
        text=None, 
        searched_via='serp'
    ), 

    
    Job(title='Senior Engineer- Artificial Intelligence - Tucows careers', url='https://boards.greenhouse.io/remotetcx/jobs/7664364003', text=None, searched_via='serp'), Job(title='Staff Machine Learning Engineer', url='https://boards.greenhouse.io/securityscorecard/jobs/7743876', text=None, searched_via='serp'), Job(title='Job Application for Senior AI Engineer at Guidepoint', url='https://boards.greenhouse.io/guidepoint/jobs/8027021002?action=apply', text=None, searched_via='serp'), Job(title='Senior AI Engineer (Engineering Productivity) - Binance', url='https://jobs.lever.co/binance/95ef7f26-27a2-488c-a51b-6596fd461539', text=None, searched_via='serp'), Job(title='AI/ML Engineer - Greenlight Financial Technology', url='https://jobs.lever.co/greenlight/cca30a59-003c-4b8c-8730-5805e0756c84', text=None, searched_via='serp'), Job(title='Senior AI Engineer - Saga', url='https://jobs.lever.co/saga-xyz/6f4e2b80-c18f-4f62-b61b-da67d257b828', text=None, searched_via='serp'), Job(title='Senior AI ML Engineer - 3Pillar', url='https://jobs.lever.co/3pillarglobal/134a9353-6542-47f9-bf7e-83223d16fcba', text=None, searched_via='serp'), Job(title='Binance - Software Engineer (AI/LLM Experience a Plus)', url='https://jobs.lever.co/binance/fe2b0bf9-95bb-40c5-959b-f991278a1cbe', text=None, searched_via='serp'), Job(title='Machine Learning Engineer - Fullscript', url='https://jobs.lever.co/fullscript/9fe372e0-537e-4cd0-a9b8-1ce57117b1c4', text=None, searched_via='serp'), Job(title='Machine Learning Engineer - Institute of Foundation Models', url='https://jobs.lever.co/ifm-us/ca550f5b-8c13-4a8e-8b03-0300b113acce', text=None, searched_via='serp'), Job(title='Best Egg - Lead Software Engineer II, AI Operations', url='https://jobs.lever.co/BestEgg/3b82aae9-9cdb-419e-9d07-5f0c43d82bde', text=None, searched_via='serp'), Job(title='e.l.f. Beauty - Lead, AI Engineer', url='https://jobs.lever.co/elfbeauty/dff799a3-aa12-46fc-a79c-cdf0ba263d9d', text=None, searched_via='serp'), Job(title='Senior Large Language Model (LLM) Operations Engineer', url='https://jobs.lever.co/npowermedicine/ae7fa790-ff1a-42fd-b037-9abb1b70dacf', text=None, searched_via='serp'), Job(title='Hugging Face - Current Openings', url='https://huggingface.co/careers', text=None, searched_via='serp'), Job(title='Senior AI / Machine Learning Engineer - RAG / LLM', url='https://www.linkedin.com/jobs/view/senior-ai-machine-learning-engineer-rag-llm-at-european-tech-recruit-4192814092', text=None, searched_via='serp'), Job(title='Artificial Intelligence Engineer Llm Jobs, Employment', url='https://www.indeed.com/q-artificial-intelligence-engineer-llm-jobs.html', text=None, searched_via='serp'), Job(title='Ai Fine Tuning Jobs, Employment', url='https://www.indeed.com/q-ai-fine-tuning-jobs.html', text=None, searched_via='serp'), Job(title='$62k-$405k Llm Ml Rag Jobs (NOW HIRING) Apr 2026', url='https://www.ziprecruiter.com/Jobs/Llm-Ml-Rag', text=None, searched_via='serp'), Job(title='Llm Fine Tuning Jobs, Employment', url='https://www.indeed.com/q-llm-fine-tuning-jobs.html', text=None, searched_via='serp'), Job(title='Agentic Agents Ai Machine Learning Jobs, Employment', url='https://www.indeed.com/q-agentic-agents-ai-machine-learning-jobs.html', text=None, searched_via='serp'), Job(title='Ai Engineer Large Language Models Jobs, Employment', url='https://www.indeed.com/q-ai-engineer-large-language-models-jobs.html', text=None, searched_via='serp'), Job(title='Large Language Models, Generative AI & Agentic Systems', url='https://jobs.apple.com/en-us/details/200636539', text=None, searched_via='serp'), Job(title='Rag Llm jobs in Remote', url='https://www.indeed.com/q-rag-llm-l-remote-jobs.html', text=None, searched_via='serp'), Job(title='Senior AI/ML Engineer - Large Language Models and Agentic ...', url='https://jaabz.com/jobs/146642-entry-level-mlai-engineer-only-usc', text='Senior AI/ML Engineer - Large Language Models and Agentic Pipelines at open systems inc. - United State | Visa Sponsorship Jobs Visa Sponsorship\n\nProgramming\n\nData Science\n\nMachine Learning Cyber Security\n\nDevops\n\nMobile\n\nProduct Management   ...    Graphic Design\n\nHr\n\nRemote\n\nProgramming\n\nData Science   ...    Marketing\n\nGraphic Design\n\nHr\n\nCountries\n\nVisa Sponsorship United State India Canada Australia United Arab Emirates   ...    Sign In Post Job Free 🎉 Found a Job?\n\nFollow\n\nContact Us\n\nContact Us # Senior AI/ML Engineer - Large Language Models and Agentic Pipelines\n\nopen systems inc. • United State\n\nRemote This Job is No Longer Active This position is no longer accepting applications\n\nAI Summary We are seeking a Senior AI/ML Engineer to design and build advanced AI-driven systems utilizing Large Language Models (LLMs) for text understanding, generation, summarization, and contextual reasoning within engineering workflows. The ideal candidate will have expertise in building solutions with commercial and open-source LLMs, agentic pipelines, and   ...    Expertise in agentic pipelines and workflow automation\n\n###### Technical Skills Required Python Transformers Pydantic FastAPI Hugging Face Azure OpenAI LangChain LlamaIndex Haystack CrewAI PostgreSQL MongoDB   ...    ###### Benefits & Perks\n\n100% remote work\n\n6+ months contract\n\nLong-term opportunity\n\n### Job Description Title: Entry-Level ML/AI Engineer\n\nLocation: Peachtree City, GA 30269 (100% REMOTE)\n\nContract: 6+ Months. Long-term   ...    We are seeking an experienced AI Applications / DevOps Engineer to architect, implement, and optimize advanced AI solutions, with a strong focus on Large Language Models (LLMs), agentic pipelines, workflow automation, and generative   ...    - Design and build advanced AI-driven systems utilizing LLMs (e.g., Azure OpenAI GPT models, Claude, Llama, Mistral, Gemini, and open-source models) for text understanding, generation, summarization, and contextual reasoning within   ...    - Architect and deploy agentic pipelines, including multi-agent systems, autonomous LLM agents, and   ...    - Fine-tune, deploy, and monitor LLMs on private or in-house datasets to address domain-specific challenges while   ...    - Bachelor’s, Master’s, or PhD in Computer Science, Artificial Intelligence, or a related field.   ...    - Strong Python skills and extensive experience with modern AI/ML/NLP libraries and frameworks, including Transformers, Pydantic, FastAPI, Hugging Face, and Azure OpenAI.   ...    ###### Job Overview\n\nPosted Date Jan 16, 2026\n\nEmployment Type Contract\n\nExperience Level Entry level Location United State\n\nCategory Programming\n\nCompany open systems inc.\n\n###### Mentioned Skills python artificial intelligence elasticsearch ai gcp fastapi aws docker devops cloud containerization research skills ai   ...    ### Senior Performance Marketer (iOS App User Acquisition)\n\nProgramming\n\n•\n\n6h ago\n\nVisa Sponsorship Relocation Remote', searched_via='exa'), Job(title='Hugging Face - Current Openings - Jobs By Workable', url='https://apply.workable.com/huggingface/', text='Hugging Face - Current Openings Hugging Face - Current Openings This website uses cookies to improve user’s experience, personalise ads and analyse traffic. You can accept all cookies, decline all optional cookies, or manage your cookie settings. To learn more, view our cookies policy. Cookies settings\nAccept allDecline all', searched_via='exa'), Job(title='Issues · Haohao-end/LMForge-End-to-End-LLMOps-Platform-for-Multi-Model-Agents · GitHub', url='https://github.com/Haohao-end/LMForge-End-to-End-LLMOps-Platform-for-Multi-Model-Agents/issues', text='Issues · Haohao-end/LMForge-End-to-End-LLMOps-Platform-for-Multi-Model-Agents · GitHub / LMForge-End-to-End-LLMOps-Platform-for-Multi-Model-Agents Public\n\nStar 711 - Pricing\n- Notifications\n- Fork 69 Labels Milestones New issue\n\n \n\nOpen\n\nClosed ### docs目录文档更新\n\n# 159\n\n· Haohao-end opened on Mar 6, 2026\n\n### RAG 命中率、延迟、成本、工具调用成功率计算可视化显示\n\n# 155 · Haohao-end opened on Mar 3, 2026\n\n### Diff 报告 + Feedback API + DS模型轻量评测\n\n# 154 · Haohao-end opened on Mar 3, 2026\n\n### 一键回放（Replay）与配置 Patch\n\n# 153 · Haohao-end opened on Mar 3, 2026\n\n### Diff：结构化比对（输出文本差异、引用差异、关键指标差异：tokens、耗时、命中数、错误类型）\n\n# 152 · Haohao-end opened on Mar 3, 2026\n\n### FunctionCallingAgent参考 扣子空间/manus类似的Agent执行步骤\n\n# 151 · Haohao-end opened on Mar 3, 2026\n\n### 提供像LangSmith这样的运行级 Trace（跨 LLM 调用、工具调用、检索、节点）\n\n# 150 · Haohao-end opened on Mar 3, 2026\n\n### Workflow debug 执行过程 每个节点对应的输出都要输出给前端显示\n\n# 149   ...    · Haohao-end opened on Mar 3, 2026\n\n### Workflow debug 失败但日志难读 可以点击后出现对应的失败信息 并调用LLM询问模型对应的解决方案\n\n# 147 · Haohao-end opened on Mar 3, 2026\n\n### Agent绑定Word工具 可以生成对应的.doc/.docx文件\n\n# 146 · Haohao-end opened on Mar 3, 2026\n\n### Agent', searched_via='exa'), Job(title='Machine Learning Engineer – Fine-Tuning and On-device AI', url='https://www.builtinsf.com/job/senior-ai-engineer/4686071', text="Machine Learning Engineer – Fine-Tuning and On-device AI - Humane | Built In San Francisco\n\n## Humane # Machine Learning Engineer – Fine-Tuning and On-device AI Sorry, this job was removed at 10:43 a.m. (PST) on Wednesday, Dec 31, 2025\n\nBe an Early Applicant\n\nEasy Apply In-Office\n\nPalo Alto, CA\n\nEasy Apply\n\nIn-Office\n\nPalo Alto, CA\n\n## Similar Jobs\n\nHP IQ ## Senior Machine Learning Engineer\n\n22 Days Ago\n\nEasy Apply\n\nIn-Office\n\nPalo Alto, CA, USA\n\nEasy Apply 120K-215K Annually\n\nMid level\n\n120K-215K Annually\n\nMid level\n\nArtificial Intelligence • Hardware • Software As an AI Engineer, contribute to HP's intelligent operating system by building orchestration architecture for LLM agents, integrating APIs, and collaborating on innovative AI features. Top Skills: ClaudeGeminiLangchainOpenaiPython\n\nHP IQ\n\n## Machine Learning Engineer\n\n22 Days Ago Easy Apply\n\nIn-Office\n\nPalo Alto, CA, USA\n\nEasy Apply\n\n150K-250K Annually\n\nSenior level\n\n150K-250K Annually   ...    As a Senior AI Engineer, you will design and implement the orchestration layer for HP's AI operating system, with responsibilities including developing memory systems, integrating LLM APIs, and improving agent performance through   ...    Top Skills: AWSDockerGCPKubernetesPythonTypescript\n\nSnap Inc.\n\n## Senior Manager, SMC Advertiser Growth   ...    HP IQ is HP’s new AI innovation lab. Combining startup agility with HP’s global scale, we’re building intelligent   ...    We’re assembling a diverse, world-class team—engineers, designers, researchers, and product minds—focused on creating   ...    Join us as we reinvent work, so people everywhere can do their best work.\n\nAbout the Role We are seeking a Machine Learning Engineer to lead the fine-tuning, optimization, and deployment of AI models for diverse tasks, with a strong emphasis on on-device inference. You will work on cutting-edge applications such as orchestration, planning, multi-agent coordination, and other intelligent decision-making systems. You will be responsible for adapting foundation models (LLMs, multimodal models) to specialized domains, making them   ...    - Collaborate with product and research teams to design intelligent, context-aware assistant capabilities.   ...    - Optimize models for low-latency inference using frameworks like OpenVINO, ONNX Runtime, QNN etc..   ...    - On-Device Optimization\n- Employee advanced techniques such as QAT, DPO, GRPO to further improve the model quality. - Explore and apply methods like full fine-tuning, LoRA, QLoRA and other types of parameter-efficient fine-tuning.   ...    - Fine-tune large language models, multimodal models, and task-specific models for orchestration, planning, and any   ...    - Track record of delivering production-ready ML solutions in latency-sensitive environments. - Familiarity with orchestration/planning architectures and techniques for AI assistants. - Experience with on-device inference optimization (OpenVINO, ONNX, QNN). - Strong understanding of transformer architectures, attention mechanisms, and PEFT techniques. - Proficiency in Python and ML frameworks ecosystem (HuggingFace, PyTorch). - 5+ years of experience in applied machine learning, including at least 3 years in LLM fine-tuning.   ...    - Experience with multi-agent systems or AI assistant orchestration. Salary Range: $120,000 - $215,000\n\nCompensation & Benefits (Full-Time Employees)   ...    Read Full Description\n\nHQ\n\n## Humane", searched_via='exa'), Job(title='NEUIR/Lang2Act', url='https://github.com/NEUIR/Lang2Act', text='# Repository: NEUIR/Lang2Act   ...    - Stars: 16\n- Forks: 0\n- Watchers: 16\n- Open issues: 0\n- Primary language: Python   ...    - Default branch: main\n- Created: 2026-01-12T10:30:36Z\n- Last push: 2026-02-17T12:32:48Z - Contributors: 2 (top: hm1229, Mr-xiongyq) ---\n\n# Lang2Act: Fine-Grained Visual Reasoning through Self-Emergent Linguistic Toolchains Source code for our paper:\n**Lang2Act: Fine-Grained Visual Reasoning through Self-Emergent Linguistic Toolchains** Paper\nModel\nDataset •\n 📖 Overview •\n ⚙️ Setup •\n ⚡️ Training •\n 🔧 Inference \n \n 📃 Evaluation •\n 🚀 Quick Start •\n 📧 Contact ## 📖 Overview  Lang2Act is a novel framework for Visual Retrieval-Augmented Generation (VRAG) that enables fine-grained visual perception and reasoning through self-emergent linguistic toolchains. Instead of relying on rigid and decoupled external tools that often introduce visual information loss, Lang2Act internalizes visual actions as linguistic tools generated and executed directly by the Vision-Language Model (VLM), allowing perception and reasoning to be unified in   ...    ```bash\nconda create -n Lang2Act python=3.10\nconda activate Lang2Act\ngit clone https://github.com/NEUIR/Lang2Act.git   ...    > **Note:** If you do not want to train the model from scratch, you may skip this section and directly proceed to   ...    Our training pipeline is built upon EasyR1 and follows a two-stage reinforcement learning paradigm designed to induce effective visual actions and structured linguistic toolchains. All training data used for Lang2Act is publicly available on Hugging Face.   ...    ```bash\nbash scripts/run_toolsrl.sh\n```\n\n## 🔧 Inference\n\nTo perform inference with a trained Lang2Act model: ```\nbash scripts/predict.sh\n``` > **Note:** The inference script uses a trained Lang2Act checkpoint and automatically downloads the required test datasets from Hugging Face. ## 📃 Evaluation We use an LLM-as-a-Judge mechanism to evaluate the correctness of the generated answers. The evaluation script calls a powerful model (e.g., Qwen2.5-72B-Instruct) to compare predictions against ground truth.   ...    ```\nbash scripts/eval.sh\n```\n\n## 🚀 Quick Start\n\nModel on Hugging Face: https://huggingface.co/xiongyq/Lang2Act-7B ```python\nfrom transformers import AutoProcessor\nfrom vllm import LLM, SamplingParams   ...    Lang2Act_PROMPT_TEMPLATE = (\n    "You are a specialized AI assistant for visual question answering.\\n"   ...    model_path = "xiongyq/Lang2Act-7B"   ...    ## Acknowledgement\n\nOur work is built on the following codebases, and we are deeply grateful for their contributions. - EasyR1\n- vllm\n\n## 📧 Contact If you have questions, suggestions, and bug reports, please give us an issue or email:\n\n```\nyqxiong54@gmail', searched_via='exa'), Job(title='[Feature] Add LoRA support for Qwen3 VL · Issue #12122 · sgl-project/sglang', url='https://github.com/sgl-project/sglang/issues/12122', text='# Issue: sgl-project/sglang #12122 - Repository: sgl-project/sglang | SGLang is a high-performance serving framework for large language models and multimodal models. | 25K stars | Python ## [Feature] Add LoRA support for Qwen3 VL - Author: @casper-hansen\n- State: closed (completed)\n- Labels: good first issue, lora - Created: 2025-10-25T16:09:17Z\n- Updated: 2026-03-06T00:38:19Z\n- Closed: 2026-03-06T00:38:19Z - Closed by: @Fridge003   ...    - [x] 1. If the issue you raised is not a feature but a question, please raise a discussion at   ...    ### Motivation As discussed in https://github.com/sgl-project/sglang/pull/10323#issuecomment-3316064039 with @mickqian, Qwen3-VL should support LoRA adapters. It was chosen to skip this since it was high priority to ship Qwen3-VL support at the   ...    ### Related resources\n\n_No response_\n\n---\n\n### Timeline **Fridge003** added label `lora`; added label `good first issue` · Oct 26, 2025 at 2:14am **@alhridoy** commented · Oct 26, 2025 at 5:59am\n\n> Hi @Fridge003 I am on it **@Fridge003** commented · Oct 26, 2025 at 6:15am > Hi @alhridoy, @Jonahcb has been working on this. \n> Maybe you can have a discussion? **@alhridoy** commented · Oct 26, 2025 at 6:17am · edited > > Hi @alhridoy, @Jonahcb has been working on this. Maybe you can have a discussion?\n> > Awesome! Then i will leave it to @Jonahcb **Jonahcb** mentioned this in PR [#12165: [Qwen3 VL] Add LoRA support for Qwen 3 VL] · Oct 26, 2025 at 7:31pm **Fridge003** closed this · Mar 6, 202', searched_via='exa'), Job(title='[RFC]: vLLM-Omni Diffusion Worker/Runner Separation & KV Manager · Issue #800 · vllm-project/vllm-omni', url='https://github.com/vllm-project/vllm-omni/issues/800', text='# Issue: vllm-project/vllm-omni #800 - Repository: vllm-project/vllm-omni | A framework for efficient model inference with omni-modality models | 4K stars | Python ## [RFC]: vLLM-Omni Diffusion Worker/Runner Separation & KV Manager - Author: @princepride\n- Association: COLLABORATOR\n- State: open\n- Assignees: @princepride   ...    Refactor the Diffusion subsystem by separating the monolithic **GPUWorker** into distinct `GPUDiffusionWorker` (infrastructure) and `GPUDiffusionModelRunner` (execution) components, and introduce `DiffusionKVManager` to manage KV   ...    The current Diffusion subsystem in vLLM-Omni uses a monolithic **GPUWorker** class that combines infrastructure setup   ...    1. **Inconsistency with AR subsystem**: The AR (Autoregressive) subsystem properly separates **GPUARWorker**   ...    This feature is primarily designed to support **BAGEL model stage separation**. BAGEL is a multimodal model that combines **AR (BAGEL-7B-MoT)** and **DiT (Diffusion Transformer)** components through a unified KV cache mechanism (**NaiveCache**). The model supports: - **Multimodal input**: Text + Image encoded via ViT + VAE into KV cache   ...    ### 1.2 Target\n\n#### Feature\n\n**In Scope:** - Separate **GPUWorker** into `GPUDiffusionWorker` (infrastructure) and `GPUDiffusionModelRunner` (execution) - `GPUDiffusionWorker` responsibilities: - CUDA device initialization\n - Distributed environment setup (NCCL, process groups)   ...    - Introduce `DiffusionKVManager` for KV cache lifecycle tracking\n\n**Out of Scope:**   ...    - **Data integrity**: All KV data transferred via connectors must be bit-exact (no corruption or loss)   ...    - **Latency overhead**: KV extraction should add < 5ms per request (GPU → CPU copy)   ...    The refactoring follows the established AR subsystem pattern with three-layer architecture:\n\n**Design Principles:** 1. **Worker = Infrastructure Only**: `GPUDiffusionWorker` handles device setup and instantiates the Runner. It does NOT   ...    **1. **vllm_omni/diffusion/worker/gpu_worker.py** (GPUWorker class)**   ...    ```python\nclass GPUDiffusionWorker:\n    """Infrastructure wrapper for diffusion model execution.""" def __init__(self, local_rank: int, rank: int, od_config: OmniDiffusionConfig):\n        ...   ...    - **Assertions**: KV data transfer integrity, successful generation.\n\n--- **Last Updated**: Jan 15, 2026 \n**Author**: Wang Zhipeng\n\n### CC List. @Gaohan123 @ZJY0516 @natureofnature @hsliuustc0106 @ywang96\n\n---\n\n### Timeline **@SamitHuang** commented · Jan 15, 2026 at 5:12pm   ...    **@princepride** commented · Jan 15, 2026 at 5:36pm · Author · edited > Because Hunyuan Image 3 uses a similar computational approach, employing a key-value cache for image generation, I have discussed with @natureofnature , we believe this represents a trend towards unified multimodal LLM architectures.   ...    **hsliuustc0106** assigned @princepride · Jan 15, 2026 at 10:48pm **@gcanlin** commented · Jan 16, 2026 at 2:41am   ...    **@ZJY0516** commented · Jan 16, 2026 at 2:50am   ...    > \n> According to offline discussion about it, the answer is no **princepride** mentioned this in PR [#822: [Core]Add GPU Diffusion Runner] · Jan 16, 2026 at 3:43pm   ...    **Vivo50E** mentioned this in issue [#1150: [RFC]: Support KV Cache CPU Offloading] · Mar 3, 2026 at 2:04am **Vivo50E** mentioned this in issue [#186', searched_via='exa'), Job(title='Job Application for Research Engineer, Agents at Anthropic', url='http://job-boards.greenhouse.io/anthropic/jobs/4017544008', text="Job Application for Research Engineer, Agents at Anthropic\n\nBack to jobs\n\n# Research Engineer, Agents Remote-Friendly (Travel-Required) | San Francisco, CA | Seattle, WA | New York City, NY\n\nApply\n\n## About Anthropic Anthropic’s mission is to create reliable, interpretable, and steerable AI systems. We want AI to be safe and beneficial for our users and for society as a whole. Our team is a quickly growing group of committed researchers, engineers, policy experts, and business leaders working together to build beneficial AI systems. ## About the role: Agentic systems are becoming an increasingly important part of how AI is deployed. Over the last year, we’ve seen rapid adoption of Claude-powered agentic systems in spaces like coding, research, customer support, network security, and more. We believe this is just the beginning, and we expect Claude to be handling much more complex tasks end-to-end or in cooperation with a human user as time goes on. We have a team striving to make Claude an even more   ...    accomplish large tasks. This team endeavors to maximize agent performance by solving challenges at whatever level is needed, whether it’s novel harness design, improved agent affordances and infrastructure, or finetuning. Given that this is a nascent field, we ask that you share with us a project built on LLMs that showcases your skill at getting them to do complex tasks. Here are some example projects of interest: design of complex agents, quantitative   ...    you hit and how to deal with them, but this is not a requirement. ### Responsibilities: - Ideate, develop, and compare the performance of different agent harnesses (eg memory, context compression, communication architectures for agents) - Design and implement rigorous quantitative benchmarks for large scale agentic tasks - Assist with automated evaluation of Claude models and prompts across the training and product lifecycle - Work with our product org to find solutions to our most vexing challenges applying agents to our products   ...    tasks ### You may be a good fit if you: - Have experience developing complex agentic systems using LLMs - Have significant software engineering and ML experience   ...    ### Strong candidates may also have experience with:\n\n- Large-scale RL on language models\n- Multi-agent systems ### Representative projects: - Design and build a novel agent harness that outperforms existing agents on coding or knowledge work benchmarks - Design and build agent affordances that unlock new capabilities for internal use and deployed products   ...    - Finetune Claude to maximize its performance using a particular set of agent tools or harness   ...    Annual Salary:\n\n$500,000 - $850,000 USD\n\n## Logistics Education requirements: We require at least a Bachelor's degree in a related field or equivalent experience.Location-based hybrid policy: Currently, we expect all staff to be in one of our offices at least 25% of the   ...    Visa sponsorship: We do sponsor visas! However, we aren't able to successfully sponsor visas for every role and every   ...    money, fees, or banking information before your first day. If you're ever unsure about a communication, don't click any links—visit anthropic.com/careers directly for confirmed position openings.   ...    We believe that the highest-impact AI research will be big science. At Anthropic we work as a single cohesive team on   ...    ## Come work with us! Anthropic is a public benefit corporation headquartered in San Francisco. We offer competitive compensation and   ...    Interested in building your career at Anthropic? Get future opportunities sent straight to your email.\n\nCreate alert ## Apply for this job\n\n*\n\nindicates a required field\n\nFirst Name\n\nLast Name\n\nEmail\n\nCountry\n\nPhone\n\nResume/CV*\n\nAttach   ...    We believe that", searched_via='exa'), Job(title='Conversational AI Large Model Researcher-Global E-commerce-Soaring Star Talent Program', url='https://joinbytedance.com/search/7508749677463767304', text='Conversational AI Large Model Researcher-Global E-commerce-Soaring Star Talent Program \n\nLife at ByteDance Our Culture Our Philosophy\n\nTeams Advertising & Sales Corporate Functions Design E-Commerce Global Operations Marketing & Communications Product Technology How We Hire\n\nApplying to ByteDance Interview Tips Frequently Asked Questions Locations\n\nEarly Careers\n\nBlog\n\nJobs\n\nApply\n\nEN日本語 Join us as we work together to inspire creativity and enrich life around the globe.\n\n \n\nLife at ByteDance Early Careers Americas Asia Pacific Europe and Middle East Early Careers FAQ\n\nTeams Technology Product Design Marketing & Communications Corporate Functions Global Operations Advertising & Sales How We Hire\n\nFAQ Interview Tips\n\nLocations\n\nBlog\n\nLegal Privacy Policy Cookie Policy\n\nOther Open Roles Careers @ TikTok Careers in China\n\nPrivacy Policy © 2012-2025 ByteDance', searched_via='exa'), Job(title='RL Training (GRPO) | Surogate', url='https://docs.surogate.ai/guides/rl-training', text='RL Training (GRPO) | Surogate\n\nOn this page Surogate supports reinforcement learning fine-tuning via GRPO (Group Relative Policy Optimization). The pipeline coordinates a vLLM inference server, a GRPO orchestrator, and the Surogate trainer. This gives you: - Surogate\'s near-SOL training throughput (LoRA, QLoRA, FP8) - Async RL pipeline (rollouts, reward computation, sample packing)\n- vLLM for fast inference and generation - Optional zero-copy GPU weight sharing between trainer and inference (co-locate mode) - Training & Evaluation with Environments   ...    model: "Qwen/Qwen3-0.6B"output_dir: ./outputsgpus: 1per_device_train_batch_size: 1sequence_len: 2048max_steps:   ...    ### Loss Objective\u200b The loss is a token-level variant of the AIPO objective(introduced in Llama-RL), without the entropy and KL   ...    # FP8 QLoRA (SM89+: RTX 40xx, L40, H100)lora: trueqlora_fp8: truerecipe: bf16# NF4 QLoRA (any GPU)lora: trueqlora_bnb:   ...    ---\n\n## Configuration Reference\u200b\n\n### Inference config\u200b Key inference options:  | Key | Default | Description |\n| --- | --- | --- | | `model` | (required) | HuggingFace model ID or local path | | `host` | `null` | Bind address (null = all interfaces) |\n| `port` | `8000` | Bind port | | `dtype` | `"auto"` | Data type (`float16`,`bfloat16`,`auto`) |\n| `max_model_len` | `null` | Maximum context length |   ...    | `dp` | `1` | Data parallelism degree |\n| `enable_lora` | `true` | Enable LoRA hot-reload |   ...    | `model.name` | `null` | HuggingFace model ID or local path |   ...    | `sampling.seed` | `null` | Sampling seed |  Environments (`env[]`): | Key | Default | Description |\n| --- | --- | --- | | `env[].id` | (required) | Environment ID from the verifiers registry | | `env[].name` | `null` | Optional human-readable name |\n| `env[].args` | `{}` | Environment-specific arguments |   ...    Client (`client.*`):  | Key | Default | Description |\n| --- | --- | --- | | `client.base_url` | `["http://localhost:8000/v1"]` | Inference server URL(s) |   ...    | `client.api_key_var` | `"VLLM_API_KEY"` | Env var name for the API key |   ...    SFT)\u200b GRPO trainer configs inherit all fields from`SFTConfig`. The most relevant ones for RL training:  | Parameter | Default   ...    | --- | --- | --- |\n| `model` | (required) | HuggingFace model ID or local path |\n| `gpus` | 1 | Number of GPUs | | `sequence_len` | 1024 | Maximum sequence length |\n| `learning_rate` | 2e-4 | Initial learning rate |   ...    | `optimizer` | adamw_8bit | Optimizer type |\n| `recipe` | bf16 | Precision recipe (bf16, fp8_hybrid, nvfp4) | | `lora` | true | Enable LoRA adapters |\n| `lora_rank` | 16 | LoRA rank | | `output_dir` | output | Parent directory containing orchestrator`run_*` subdirs |  All LoRA, QLoRA, precision, and multi-GPU settings from SFT are available. See the Configuration guide for the full list.   ...    ## See also\u200b  - Step Semantics\n- Loss Objective\n\nCo-locate Mode Details - How weight sharing works\n- Automatic gpu_memory_utilization\n- Multi-GPU co-locate\n- Supported quantization formats   ...    - QeRL Adaptive Quantization Noise\n- On-Policy Distillation\n- Learning Rate\n- Masking Thresholds\n- KL Penalty   ...    Configuration Reference - Inference config\n- Orchestrator config\n- Trainer config (inherited from SFT)\n- GRPO-specific', searched_via='exa'), Job(title='Job Application for Generative & Agentic AI Engineer at Babel Street', url='https://job-boards.greenhouse.io/babelstreet/jobs/7531339', text='Job Application for Generative & Agentic AI Engineer at Babel Street\n\nBack to jobs # Generative & Agentic AI Engineer\n\nReston, Virginia, United States; Somerville, Massachusetts, United States\n\nApply Babel Street is the trusted technology partner for the world’s most advanced identity intelligence and risk operations. We deliver advanced AI and data analytics solutions providing unmatched, analysis-ready data regardless of language,   ...    systems. Babel Street empowers government and commercial organizations to transform high-stakes identity and risk   ...    around the world. Babel Street is headquartered in Reston, Virginia, with regional offices in Boston, MA and Cleveland, OH, and international offices in Australia, Canada, Israel, Japan, and the U.K. For more information, visit www.babelstreet.com. ROLE SUMMARY As an Engineer on the Generative & Agentic AI team, you will play a hands-on role in building, deploying, and operating AI capabilities that power Babel Street’s intelligence applications. You will work closely with senior AI leaders, product teams, and engineers to implement generative and agentic AI solutions that support investigative, analytical,   ...    This is an execution-focused role for an engineer with strong foundations in machine learning and generative AI who is excited to work on real-world, mission-driven applications. You will contribute directly to LLM and SLM pipelines,   ...    safe, reliable, cost-efficient, and production-ready. This is a hybrid role to be based out of either our Reston, VA/Washington DC office or our Somerville MA office. ROLE FOCUS\n\nThis role spans three practical execution areas:\n\nGenerative AI & Model Development You will help implement and operate LLM- and SLM-based systems, contributing to prompt development, fine-tuning, evaluation, and inference optimization. You will support retrieval-augmented generation (RAG) pipelines, embeddings, and grounding techniques to ensure AI outputs are accurate, explainable, and aligned with intelligence use cases. Agentic AI & Workflow Automation You will assist in building and integrating agent-based workflows that automate analytical tasks, connect platform   ...    AI Engineering & Production Delivery You will help productionize AI capabilities using modern AI SDLC tools and practices, contributing to evaluation,   ...    established governance frameworks to ensure AI features are measurable, reliable, and cost-aware. KEY RESPONSIBILITIES - Implement and maintain LLM and SLM pipelines, including prompt engineering, inference, and evaluation. - Support RAG pipelines, embeddings, and retrieval systems used in intelligence applications. - Assist in building agent workflows that automate analytical or operational tasks.   ...    - Follow established AI governance, safety, and cost-optimization practices.\n\nQUALIFICATIONS\n\nRequired - 5+ years of experience in software engineering, machine learning, or applied AI roles. - Hands-on experience working with LLMs and/or SLMs, including prompting, inference, or fine-tuning. - Experience building or contributing to RAG pipelines, embeddings, or retrieval systems. - Familiarity with agent-based systems or workflow automation (academic, professional, or open-source).   ...    Babel Street is an equal opportunity/affirmative action employer. All qualified applicants will receive consideration   ...    more information about such accommodations. Range for this position based on qualifications and experience\n\n$140,000 - $180,000 USD\n\nCreate a Job Alert Interested in building your career at Babel Street? Get future opportunities sent straight to your email. Create alert\n\n## Apply for this job\n\n*\n\nindicates a required field\n\nAutofill with MyGreenhouse\n\nFirst Name\n\nLast Name Preferred First Name\n\nEmail\n\n', searched_via='exa'), Job(title="Some remote AI, data, and language roles I'm seeing hiring right now", url='https://www.facebook.com/groups/573518645176483/posts/809888104872868/', text='AI WORK HIVE - OUTLIER, ALIGNERR, DATAANNOTATION, STELLAR, INVISIBLE ETC. | Some remote AI, data, and language roles I’m   ...    AI WORK HIVE - OUTLIER, ALIGNERR, DATAANNOTATION, STELLAR, INVISIBLE ETC. | Some remote AI, data, and language roles   ...    AI WORK HIVE - OUTLIER, ALIGNERR, DATAANNOTATION, STELLAR, INVISIBLE ETC. ·\nJoin\nRobert Norinder · 4d · Shared with Public group\nSome remote AI, data, and language roles I’m seeing hiring right now I track remote AI jobs each week and send out a curated list. Sharing a shortened version here in case it’s useful. To keep this readable, I’m limiting it to a maximum of 2 roles per category. These are the ones that stood out most   ...    All links go directly to company hiring pages.\nPay is listed where available. These all appear legitimately open right now.\nAI Training & Evaluation\nData Annotation Contributor — Human Signal Remote — $20/hr Dataset labeling and evaluation work supporting large-scale AI training pipelines. This sits closer to the   ...    https://job-boards.greenhouse.io/humansignal/jobs/5823725004\nAI Trainer (Part-time) — Kastle   ...    https://jobs.ashbyhq.com/.../824fc6f9-b2ff-44ea-bc61...\nAnnotation & Data Work   ...    https://jobs.ashbyhq.com/.../6289c429-7e46-4c96-9c58...\nFreelance Annotator (English) — Toloka Remote (LatAm) — $10/hr Entry-level annotation and review tasks used to improve AI outputs. One of the more accessible ways to get started in   ...    https://apply.workable.com/j/4086A366AA\nAudio & Speech Data   ...    https://app.opentrain.ai/job.../cmmsnoabk000n04l43jq3gaa7   ...    AI Engineer — Mind Computing\nRemote (US) — $115k–$125k Full-time role building and deploying AI systems rather than evaluating them. Fewer of these roles show up compared to   ...    https://mind-computing.breezy.hr/.../edde74233ea2-ai...\nAI Engineer (Intern) — Juniper Square Remote (US and Canada) — \\~$50/hr High-paying internship working on production systems inside a real company environment. Likely more hands-on than typical intern roles. https://jobs.ashbyhq.com/.../48d40321-aba6-46a8-a438...\nAI-Adjacent Roles\nAI Analyst — BH Remote — $85,000–$95,000 Role focused on turning AI outputs into usable insights inside business workflows. This is where a lot of real-world   ...    https://www.paycomonline.net/.../C8CA71BADF7E.../jobs/575059   ...    The pattern is still the same: most hiring is not for building models, but for improving them. Evaluation, annotation, language work, and applied roles are where a lot of the demand is. If you want the full weekly list (15 roles), I send it out here:\nhttps://jobsignal.work If you want to browse more broadly, there are currently 50,000+ remote roles listed here: https://alljobs.work   ...    alljobs.work\nAllJobs.work', searched_via='exa'), Job(title='Hugging Face - Current Openings - Jobs By Workable', url='https://apply.workable.com/huggingface/', text='Hugging Face - Current Openings Hugging Face - Current Openings This website uses cookies to improve user’s experience, personalise ads and analyse traffic. You can accept all cookies, decline all optional cookies, or manage your cookie settings. To learn more, view our cookies policy. Cookies settings\nAccept allDecline all', searched_via='exa'), Job(title='Jobs for AI engineer from Insight Global', url='https://jobs.insightglobal.com/find_a_job/?miles=False&remote=true&srch=AI+engineer', text='Jobs for AI engineer from Insight Global\n\nEnglish (US)\n\nEnglish (UK) - Contact Us\n- 855-485-8853\n\nJoin Now Sign In\n\n   ...    Whether you\'re looking for a new career or your next assignment, take a look at some of our open positions and find the   ...    Change Filters\n\n# Job Search Results for AI engineer\n\nSort and Filter | 68 Results for AI engineer | Save This Search   ...    {"JobID":480853,"JobType":["Contract"],"EmployerID":null,"Location":{"Latitude":-122.67,"Longitude":45.51,"Distance":nu   ...    140000)\\/","Description":"A leading insurance company in the Pacific Northwest is seeking an AI Data Engineer to help design, implement, and scale next-generation AI solutions. This role will focus on building and enabling agentic AI systems while leveraging modern   ...    https://insightglobal.com/workforce-privacy-policy/.","Title":"AI Engineer","City":"Portland","ExpirationDate":null,"PriorityOrder":0,"Requirements":"- Design, build, and deploy agentic AI solutions that automate, orchestrate, and enhance data-driven workflows.- Develop and maintain scalable data   ...    concepts.","Industry":"Computer Engineering","Country":"US","Division":"IT","Office":null,"IsRemoteJob":true,"IsInternalJob":false,"ExtraValues":null,"   ...    A leading insurance company in the Pacific Northwest is seeking an AI Data Engineer to help design, implement, and   ...    Save\n\nShare\n\nApply\n\nSave\n\nShare\n\nApply\n\nSave\n\nShare\n\nQuick Apply\n\nAI Engineer\n\nHuntington Beach, CA\n\n| Software Engineering\n\n|\n\nPerm\n\n|\n\n$120k - $140k (estimate) {"JobID":483257,"JobType":["Perm"],"EmployerID":null,"Location":{"Latitude":-118,"Longitude":33.72,"Distance":null},"St ate":"California","Zip":"92647","ReferenceID":"SDG-425c8ef9-9668-4b4b-9600-8be431d984e8","PostedDate":"\\/Date(1768507366 000)\\/","Description":"Overview:Insight Global is seeking a hands-on AI Engineer to design, build, and deploy AI/ML solutions using LLMs, generative AI, and modern ML frameworks. This role focuses on developing production-ready models, RAG pipelines, and automation that improve business operations.Responsibilities:? Design and develop Generative AI and LLM-based models for text, audio, and chatbot use cases.? Build RAG pipelines using vector databases, embeddings, chunking, indexing, and retrieval   ...    https://insightglobal.com/workforce-privacy-policy/.","Title":"AI Engineer","City":"Huntington Beach","ExpirationDate":null,"PriorityOrder":0,"Requirements":"? 2+ years in AI engineering roles ? At least 4+ years of Machine learning experience.? 3+ years building production AI/ML solutions on Azure or Snowflake.? Hands-on experience with LLMs, deep learning, Python, TensorFlow/PyTorch, and AI evaluation frameworks (RAGAs, TruLens).? Proven experience delivering agentic frameworks and GenAI projects to production.? Strong grounding in NLP, model evaluation,   ...    preferred.","Industry":"Software   ...    Overview:Insight Global is seeking a hands-on AI Engineer to design, build, and deploy AI/ML solutions using LLMs,   ...    pipelines, and automation that improve business operations.Responsibilities:? Design and develop Generative AI and LLM-based models for text, audio, and chatbot use cases.? Build RAG pipelines using vector databases, embeddings,   ...    Description":"We are seeking a Machine Learning Engineer to join a growing AI and data engineering team focused on building   ...    Microsoft-specific LLMs","Industry":"Programmer /  We are looking to hire six contractors to build a library of demo   ...    solutions for achieving functional AI/Gen AI vision. As the AI/LLM Engineer you are expected to have expertise in in Gen AI development (Multi agentic architecture, Agents orchestration, RAG, LLM evaluations, APIs development etc.).   ...    executives. This position is 100% remote but must sit in India working 11:00-7:00 PM IST.Pay-rate: $15-20/hour USD. Exact  Global\\u0027s Workforce Privacy Policy: https://insightglobal.com/workforce-privacy-policy/.","Title":"AI', searched_via='exa'), Job(title='Remote AI and data job listings available - Facebook', url='https://www.facebook.com/groups/731959757473755/posts/1800949617241425/', text='AI, data, and language roles I’m seeing hiring right now | Facebook   ...    ]\nLog In\nForgot Account?\n\nRemote AI and data job listings available Summarized by AI from the post below\n\n\n##\nData Annotation\nRobert Norinder   ...    I track remote AI jobs each week and send out a curated list. Sharing a shortened version here in case it’s useful.   ...    All links go directly to company hiring pages.\nPay is listed where available. These all appear legitimately open right now.\nAI Training & Evaluation\nData Annotation Contributor — Human Signal Remote — $20/hr Dataset labeling and evaluation work supporting large-scale AI training pipelines. This sits closer to the   ...    https://job-boards.greenhouse.io/humansignal/jobs/5823725004\nAI Trainer (Part-time) — Kastle   ...    https://jobs.ashbyhq.com/.../824fc6f9-b2ff-44ea-bc61...\nAnnotation & Data Work   ...    https://jobs.ashbyhq.com/.../6289c429-7e46-4c96-9c58...\nFreelance Annotator (English) — Toloka Remote (LatAm) — $10/hr Entry-level annotation and review tasks used to improve AI outputs. One of the more accessible ways to get started in   ...    https://apply.workable.com/j/4086A366AA\nAudio & Speech Data   ...    https://app.opentrain.ai/job.../cmmsnoabk000n04l43jq3gaa7   ...    https://apply.workable.com/volga-partners/j/447505F2F0/\nTechnical & AI Builder Roles AI Engineer — Mind Computing\nRemote (US) — $115k–$125k Full-time role building and deploying AI systems rather than evaluating them. Fewer of these roles show up compared to   ...    https://mind-computing.breezy.hr/.../edde74233ea2-ai...\nAI Engineer (Intern) — Juniper Square Remote (US and Canada) — \\~$50/hr High-paying internship working on production systems inside a real company environment. Likely more hands-on than typical intern roles. https://jobs.ashbyhq.com/.../48d40321-aba6-46a8-a438...\nAI-Adjacent Roles\nAI Analyst — BH Remote — $85,000–$95,000 Role focused on turning AI outputs into usable insights inside business workflows. This is where a lot of real-world   ...    https://www.paycomonline.net/.../C8CA71BADF7E.../jobs/575059   ...    The pattern is still the same: most hiring is not for building models, but for improving them. Evaluation, annotation, language work, and applied roles are where a lot of the demand is. If you want the full weekly list (15 roles), I send it out here:\nhttps://jobsignal.work If you want to browse more broadly, there are currently 50,000+ remote roles listed here: https://alljobs.work   ...    alljobs.work\nAllJobs.work -', searched_via='exa'), Job(title='Hanfried-Nguegan/AI-Prompt-Refiner-Agent', url='https://github.com/Hanfried-Nguegan/AI-Prompt-Refiner-Agent', text='# Repository: Hanfried-Nguegan/AI-Prompt-Refiner-Agent\n\nAI Prompt Refinement Agent built using n8n and TypeScript - Stars: 1\n- Forks: 0\n- Watchers: 1\n- Open issues: 0\n- Primary language: TypeScript - Languages: TypeScript (94.9%), Shell (3.3%), JavaScript (1.8%)\n- License: MIT License (MIT)\n- Default branch: main - Created: 2025-12-22T18:16:33Z\n- Last push: 2026-01-05T17:00:58Z\n- Contributors: 1 (top: Hanfried-Nguegan) ---\n\n# Prompt Refiner A modular, context-ready prompt refinement tool that connects your editor, terminal, and IDE to an n8n automation workflow. Built with TypeScript, designed for speed and flexibility.   ...    ## Overview\n\nPrompt Refiner gives you three seamless ways to refine your prompts: - **In VS Code** — Select text, hit Cmd+Shift+P, run "Refine Selection", and watch it improve in place. - **From Terminal** — Pipe your prompt to the CLI, get the refined version back on your clipboard instantly.   ...    All three mechanisms use the same underlying engine: a strict TypeScript core that sends your prompt to your n8n   ...    ## Prerequisites\n\nYou\'ll need: - **Bun** (v1.0+ JavaScript runtime) — Install here - **n8n** instance (free cloud or self-hosted) — Create account - **OpenAI API key** (or another LLM provider configured in n8n) ## Quick Start\n\n### 1. One-Line Install (Recommended) ```bash\ngit clone https://github.com/Hanfried-Nguegan/AI-Prompt-Refiner-Agent.git\ncd AI-Prompt-Refiner-Agent   ...    ### 2. Set Up n8n Workflow\n\nYou don\'t need to build the workflow from scratch — it\'s included in the repo.   ...    1. Go to Workflows → New → Import from file\n2. Upload `n8n/refiner-workflow.json` from this repo   ...    - **CallModel** — Calls OpenAI\'s gpt-4o-mini to refine your prompt   ...    ```bash\nbun install\nbun run build\nbun link  # Makes prompt-refiner available globally\n```\n\n## How It Works ### The Pipeline ```text\nYour prompt → lib.ts (HTTP client + retry logic) → n8n webhook → AI refinement → Result back to you\n``` ### Three Interfaces, One Engine - **CLI** (`src/refine.ts`) — Reads stdin or clipboard, writes result to clipboard   ...    ## Configuration\n\nThese environment variables control timeout, retry, and cache behavior:   ...    | `REFINER_WEBHOOK_URL` | (required) | Your n8n endpoint — where prompts get sent |   ...    ## Architecture\n\nThe codebase is organized into layers:   ...    **Strict TypeScript throughout.** Compilation uses `strict: true`, `exactOptionalPropertyTypes`, and `noUncheckedIndexedAccess` for maximum type safety. Built with dependency injection — each component gets what it needs, making it easy to test and extend. ### How n8n Workflow Works\n\nThe included workflow (`n8n/refiner-workflow.json`) does this: 1. **Receive webhook call** — Prompt Refiner sends your prompt here   ...    ```bash\nbun install          # Install dependencies\nbun run build        # Compile TypeScript to dist/\n```   ...    ## Why This Approach?\n\nThree interfaces solve different problems: - **CLI** is perfect for scripts and one-off refinements - **Daemon** is perfect for interactive use — no startup overhead, fast responses - **VS Code** is perfect for editing — stay in your editor, refine inline One engine keeps them in sync', searched_via='exa'), Job(title='CoreAgent-Project/CoreAgent', url='https://github.com/CoreAgent-Project/CoreAgent', text='# Repository: CoreAgent-Project/CoreAgent\n\nLLM Agent framework with Stateful Tools. - Stars: 28\n- Forks: 4\n- Watchers: 28\n- Open issues: 2\n- Primary language: Python   ...    - Created: 2025-03-18T19:07:38Z\n- Last push: 2025-07-09T22:14:57Z\n- Contributors: 1 (top: ComposerKevin)\n- Releases: 3 - Latest release: v0.1.2-alpha (2025-05-01T15:07:20Z) ---\n\n \n \n \n \n \n\n \nSimplest Agent Framework with Stateful Tools\n \n\n \n 中文 \n \n \n| Documentation | Discord |\n \n\n--- CoreAgent is a lightweight and intuitive framework designed to make building intelligent agents straightforward. Focusing on simplicity, CoreAgent allows you to quickly integrate language models with custom tools to create powerful   ...    ## Abandon MCP! NOW! Use AIML, instead! LLMs are very bad at outputting escaped characters in their outputs, so you will often see messed-up code in your LLM   ...    That\'s why `AIML` comes to the rescue, we have proposed a new method of communicating with LLM which addresses this   ...    ## Stateful Tools\n\nIntroducing **Stateful Tools**, which can be shared across multiple agents. ```python\nfrom coreagent import Agent class MyStatefulTool:\n  def __init__(self):\n    self.state = 0\n  def add_state(self, n: int):\n    self.state += n   ...    agent_1 = Agent.with_tools(shared_tool)\nagent_2 = Agent.with_tools(shared_tool)\nagent_1.chat("add by 10")   ...    ## Installation\n\nTo install CoreAgent, simply use pip:\n\n```bash\npip install coreagent\n```\n\n## Getting Started Try out simple `guard_and_theif.py` example with **OpenAI** official endpoint: ```shell\npython ./examples/guard_and_theif.py \\\n  -u "https://api.openai.com/v1/" \\\n  -m "gpt-3.5-turbo" \\   ...    ```python\nfrom coreagent import Agent, set_default_config_from_args\nimport urllib.request\nimport json   ...    s = Agent()\ns.register_tool(IPTool())\n\ns.chat("What\'s my IP address? ")\n```\n\n## Roadmap - [x] Basic universal agent framework. - [x] Make `guided_grammar` optional, allow general LLM usage (DeepSeek API, GPT3.5/4/4o API, Qwen API, etc. ) - [x] More intuitive simplified examples, allowing hands-on try-outs.\n- [ ] Multi-modal input. - [ ] RAG-based memory module.\n- [ ] Integrate MCP client module. (MCP is just a propaganda, useless stuff) ## Contributing Contributions to CoreAgent are welcome! If you have ideas for improvements, bug fixes, or new features, please feel   ...    ## License Brought to you by Shanghai Glacies Technologies Co,. LTD. \nGNU Lesser General Public License v3.0 https://www.gnu.org', searched_via='exa'), Job(title='tangpan360/MicroRCA-Agent', url='https://github.com/tangpan360/MicroRCA-Agent', text='Repository: tangpan360/MicroRCA-Agent 2025 CCF International AIOps Challenge | Track 1: Microservice Root Cause Localization Based on Large Model Agents |   ...    - Stars: 218\n- Forks: 19\n- Watchers: 218\n- Open issues: 3\n- Primary language: Python   ...    - Last push: 2026-01-14T10:19:09Z\n- Contributors: 2 (top: tangpan360, ShixiangTang) ---\n\n# MicroRCA-Agent: LLM-Agent-Based Microservice Root Cause Analysis arxiv badge\nGitHub Repo stars   ...    English | 中文\n\n## 2025 International AIOps Challenge (Finals Top 5, 48.52 points)\n\n## Project Overview This project is an intelligent operations solution based on multi-modal data analysis, capable of processing Log, Trace, and Metric data for fault analysis and root cause localization through large language models. It adopts a modular architecture design with five core modules: data preprocessing module, log fault extraction module, trace fault   ...    │   ├── agent/  # Intelligent agent module\n│   │   ├── __init__.py  # Package initialization file │   │   ├── agents.py  # Agent implementation\n│   │   ├── llm_config.py  # LLM configuration for agent model list   ...    ```  ### 5. Advanced Optimization Recommendations for the Solution  The current project has implemented a multimodal   ...    building a knowledge base of O&M experience documents. These resources are not available to non-professional O&M teams. If you have access to relevant O&M resources and implementation conditions, you can optimize the current solution in the following directions, which will significantly improve the accuracy of root cause localization:  - **Precise   ...    finally review business logs") into the LLM prompt logic. This guides the intelligent agent to reason in accordance with standardized pathways.  - **O&M Document RAG Optimization**: Establish a knowledge base of O&M experience documents (e.g., historical fault cases, component fault manuals). Leverage RAG (Retrieval-Augmented Generation) technology to enable the LLM to reference historical experience during analysis, thereby enhancing the accuracy and   ...    Since the project dataset and weight files are managed using Git LFS, you need to install and configure Git LFS before   ...    ## Configuration\n\n### Environment Variables Please add your own DeepSeek official API keys by configuring the following environment variables in the `src/.env`   ...    - `KEJIYUN_API_KEY`: LLM API key\n- `KEJIYUN_API_BASE`: LLM API base address  ### Model Configuration   ...    ### 🏆 Evaluation Platform  This project participates in the **CCF AIOps 2025 Challenge** in the "LLM-Agent-Based Microservice Root Cause Analysis" track. **Official Evaluation Platform**: https://challenge.aiops.cn/home/competition/1963605668447416345 ### 📋 Evaluation Process\n\n#### **Step 1: Platform Registration and Login** 1. Visit the evaluation platform and complete account registration   ...    Thanks to the CCF AIOps 2025 Challenge organizing committee for providing high-quality datasets and a good competition environment, offering our team a valuable learning and exchange platform.  This project participated in: **Track 1: LLM-Agent-Based Microservice Root Cause Analysis** Competition website: CCF AIOps 2025 Challenge ## Citation ```bibtex\n@article{tang2025microrca, title={MicroRCA-Agent: Microservice Root Cause Analysis Method Based on Large Language Model Agents}, author={Tang, Pan and Tang, Shixiang and Pu, Huanqi and Miao, Zhiqing and Wang, Zhixing}, journal={arXiv preprint arXiv:2509.15635},\n  year={2025}', searched_via='exa'), Job(title='AutoGen：多智能体协作系统开发的创新解决方案 - AtomGit | GitCode博客', url='https://blog.gitcode.com/2a38f50839494ce4584f0eccbf892916.html', text='AutoGen：多智能体协作系统开发的创新解决方案 - AtomGit | GitCode博客\n\n 首页\n\n/ AutoGen：多智能体协作系统开发的创新解决方案 # AutoGen：多智能体协作系统开发的创新解决方案\n\n2026-03-16 05:15:15作者：齐添朝\n\nhttps://gitcode.com/GitHub_Trending/au/autogen ## 一、核心价值：重新定义AI应用开发范式 AutoGen作为下一代大型语言模型应用开发框架，通过多智能体协作架构彻底改变了传统AI应用的开发模式。其核心价值在于提供了一个灵活而强大的平台，让开发者能够轻松构建由多个智能体组成的协作系统，这些智能体可以自主运行或与人类无缝协作，共同   ...    ### 核心要点\n\n- AutoGen通过多智能体协作突破单一模型能力边界\n- 提供标准化消息协议和灵活通信机制\n- 支持人类-AI混合协作模式\n- 模块化设计确保高度可扩展性\n\n## 二、实践路径：从环境搭建到应用部署 ### 2.1 环境准备与安装\n\nAutoGen支持Python 3.10及以上版本，通过简洁的安装命令即可快速搭建开发环境： ```\n# 基础安装：核心框架与OpenAI扩展\npip install -U "autogen-agentchat" "autogen-ext[openai]"   ...    - Core API层：提供基础消息传递、事件驱动和分布式运行时支持\n- AgentChat API层：简化的高级API，支持快速原型开发\n- Extensions API层：扩展生态系统，支持第一方和第三方扩展   ...    - 环境搭建只需简单的pip命令和API密钥配置\n- 分层架构设计满足不同层级的开发需求\n- 单个智能体创建仅需几行代码即可完成\n- 通过AgentTool实现智能体间能力共享与协作\n\n## 三、深度探索：核心技术与高级应用   ...    | 特性 | AutoGen | LangChain | LlamaIndex |\n| --- | --- | --- | --- |\n| 核心定位 | 多智能体协作框架 | LLM应用开发框架 | 知识增强引擎 | | 智能体模型 | 一等公民，丰富的交互模式 | 有限支持，主要作为工具使用 | 不支持 |\n| 通信机制 | 完善的消息协议，支持复杂交互 | 简单函数调用，缺乏标准化 | 不适用 |   ...    AutoGen最适合需要构建复杂多智能体系统的场景，而LangChain更适合快速构建单智能体LLM应用，LlamaIndex则专注于知识管理和检索增强。\n\n### 3.3 性能优化最佳实践   ...    ### 3.5 扩展性开发指南\n\nAutoGen提供了丰富的扩展点，允许开发者定制和扩展框架能力：\n\n自定义智能体：继承基础Agent类实现特定领域智能体   ...    ```\n\n开发新工具：创建可被智能体使用的工具\n\n实现中间件：添加自定义消息处理逻辑\n\n扩展模型支持：集成新的LLM模型或API\n\n### 核心要点 - 智能体通信协议和中间件系统是AutoGen的两大技术支柱\n- 与同类框架相比，AutoGen在多智能体协作方面具有显著优势\n- 性能优化可通过智能体池化、缓存和异步处理实现\n- 分布式部署架构确保系统的高可用性和可扩展性 - 丰富的扩展点支持定制化开发，满足特定业务需求 ## 四、总结与学习资源\n\nAutoGen为构建复杂AI应用提供了全新的思路和工具，通过多智能体协作模式，开发者可以构建更强大、更灵活的AI系统。无论是快速原型开发还是大规模生产部署，AutoGen都能提供合适的API和工具支持。 ### 学习资源推荐 - 官方文档：docs/design/01 - Programming Model.md\n- 核心API参考：src/AutoGen.Core/\n- 示例代码：项目中的samples目录包含丰富的使用示例 - 最佳实践指南：docs/design/05 - Services.md 通过AutoGen，开发者可以充分发挥大型语言模型的潜力，构建下一代智能应用，解决更复杂的业务问题。无论你是AI研究人员还是应用开发者，AutoGen都能为你提供强大的技术支持，推动AI应用开发进入新的阶段。 https://gitcode.com/GitHub_Trending/au/autogen\n\n登录后查看全文\n\n### 相关内容推荐  1 AutoGen多智能体框架全解析：从概念到实战的AI协作系统构建指南  2 AutoGen多智能体框架：构建下一代AI协作系统的全指南  3 智能协作框架AutoGen：零基础到架构师的AI应用开发指南  4 AutoGen多智能体框架：重构AI应用开发的技术范式与实践指南  5 告别AI开发复杂性：AutoGen多智能体框架如何重构智能应用构建流程  6 AutoGen：多智能体协作框架如何重塑AI应用开发  7 革新性多智能体开发：AutoGen全流程AI应用构建指南  8 建筑规划新范式：AutoGen智能体如何重构设计流程  9 3个维度解析AutoGen：多智能体协作分布式AI应用实战指南  10 AutoGen多智能体框架：构建下一代AI协作系统的全栈解决方案 热门项目推荐\n\n相关项目推荐 - \n-  GLM-5 智谱 AI 正式发布 GLM-5，旨在应对复杂系统工程和长时域智能体任务。Jinja00 - [ GLM-5-w4a8 GLM-5-w4a8基于混合专家架构，专为复杂系统工程与长周期智能体任务设计。支持单/多节点部署，适配Atlas 800T   ...    -  jiuwenclaw JiuwenClaw 是一款基于openJiuwen开发的智能AI Agent，它能够将大语言模型的强大能力，通过你日常使用的各类通讯应用，直接延伸至你的指尖。Python0241 -  Q Qwen3.5-397B-A17B Qwen3.5 实现了重大飞跃，整合了多模态学习、架构效率、强化学习规模以及全球可访问性等方面的突破性进展，旨在为开发者和企业赋予前所未有的能力与效率。Jinja00   ...    -  electerm 开源终端/ssh/telnet/serialport/RDP/VNC/Spice/sftp/ftp客户端(linux, mac, win)JavaScript00\n- - \n-  A autogen A programming framework for agentic AIPython391 -  A AutoGPT AutoGPT is the vision of accessible AI for everyone, to use and to build on. Our mission is to provide   ...    -  A autogen-ui Web UI for AutoGen (A Framework Multi-Agent LLM Applications)TypeScript00 -  A AutoAgent "AutoAgent: Fully-Automated and Zero-Code LLM Agent Framework"Python120   ...    BiliTools全场景解析指南：高效管理B站资源的跨平台解决方案  5个core83核心能力：提升Node.js开发效率的全方位解决方案  AI模型云端部署无代码实践：从本地训练到生产服务的完整指南  macOS平台Windows启动盘制作工具：WindiskWriter全面指南 [   ...     flutter_flutter 暂无简介Dart881211 \n\n[ MindSpeed-LL', searched_via='exa'), Job(title='Ai Engineer – Agentic And Rag Systems Jobs in United States', url='https://jobright.ai/jobs/ai-engineer-%E2%80%93-agentic-and-rag-systems-jobs-in-united-states', text='Ai Engineer – Agentic And Rag Systems Jobs in United States | Jobright\n\nJOBS\n\nRecommendedLiked\n\n0\n\nApplied\n\n0\n\nExternal 0\n\n# Ai Engineer – Agentic And Rag Systems in united states (1000+)\n\nFeedback\n\nUnited States\n\nCompany Experience Level\n\nJob Type\n\nWork Model\n\nDate Posted\n\nAll Filters ## Machine Learning Engineer III - Generative AI - Windreich Department of Artificial Intelligence & Human Health   ...    NYFull-time$132K/yr - $198K/yrOnsiteMid, Senior Level4+ years expLess than 25 applicantsASK ORIONAPPLY NOWMATCH   ...    ## AI Engineering Intern (Generative & Agentic AI) 9 hours agoBe an early applicantBoston Scientific/Medical Device · Healthcare · PublicMarlborough, MAInternship$43K/yr - $74K/yrHybridIntern1+ years expLess than 25 applicantsASK ORIONAPPLY NOWMATCH SCORENo H1B   ...    ## Senior Software Engineer – Agent Systems [13 hours agoKraken/Crypto & Web3 · Bitcoin · Late StageUnited StatesFull-time$110K/yr - $221K/yrRemoteSenior Level5+   ...    ## Lead AI Engineer, Agent Systems [16 hours agoSPECTRAFORCE/Enterprise Software · Consulting · Late StagePalo Alto, CAFull-time$185K/yr -   ...    ## LLM Engineer (RAG & Agentic AI) [17 hours agoApplicantz/Computer Software · Growth StageUnited StatesContract$58/hr - $58/hrRemoteMid Level154   ...    ## Lead Generative AI Architect (Agentic AI & LLM Systems)   ...    ## Staff AI Systems Engineer — Agentic Platforms [1 day agoKindo/Artificial Intelligence (AI) · Enterprise Software · Growth StageVenice, CA, San Francisco, Hybrid,   ...    ## Language Engineer, Artificial General Intelligence - Data Services   ...    ## Summer 2026 - TCAD Engineer Intern, AI Agent Systems for Physical Sciences (7371) [2 weeks agoTSMC/Semiconductor · Electronics · PublicSan Jose, CAInternship$37/hr - $44/hrOnsiteInternStart in 2026   ...    ## Senior Software Engineer - Agentic AI Analytics (Rust / Data Systems) [1 month agoNoor Staffing Group/Human Resources · Staffing Agency · Late StageLos Angeles, CA, USFull-time$200K/yr -   ...    ## Software Engineer, Agentic AI Systems 1 week agoMoveworks/Artificial Intelligence (AI) · Cloud Computing · Late StageMountain View, CAFull-timeOnsiteNew Grad, Entry Level200+ applicantsASK ORIONAPPLY NOWMATCH SCOREH1B Sponsor Likely ## AI Platform Engineer - LLM Agents & RAG [6 days agoSignant Health/Big Data · Healthcare · Late StageUnited StatesFull-timeRemoteSenior Level5+ years exp200+   ...    ## Machine Learning Engineer — Large Language Models, Generative AI & Agentic Systems 1 month agoApple/Artificial Intelligence (AI) · Digital Media · PublicSan Francisco, CAFull-time$147K/yr - $272K/yrOnsiteSenior Level76 applicantsASK ORIONAPPLY NOWMATCH SCOREComp. & BenefitsH1B Sponsor Likely ## RAG + Agentic AI Engineer (India) (Remote) [3 months agoCodvo.ai/Information Technology · Growth StageUnited StatesFull-timeRemoteMid, Senior Level36   ...    ## Lead Frontend Engineer (UI/UX) – AI Agent', searched_via='exa'), Job(title='Applied AI Engineer - LLM & NLP - Toku', url='https://toku.co/careers/applied-ai-engineer-llm-nlp/', text="Applied AI Engineer - LLM & NLP - Toku Toku is ranked #159 in The Financial Times' High-Growth Companies in APAC! Read more here.   ...    - Help Centre Need help? Get support, read our FAQs, and find info on our products Contact us\n\n# Applied AI Engineer – LLM & NLP\n\nEngineering\n\nRemote job\n\nApplied AI Engineer – LLM & NLP Job description At Toku, we create bespoke cloud communications and customer engagement solutions to reimagine customer experiences for enterprises. We provide an end-to-end approach to help businesses overcome the complexity of digital transformation and deliver mission-critical CX through cloud communication solutions. Toku combines local strategic consulting expertise, bespoke technology, regional in-country infrastructure, connectivity, and global reach to serve the diverse needs of enterprises operating at scale. Headquartered in Singapore, Toku supports customers across APAC and beyond, with a growing footprint across global markets. As an Applied AI Engineer at Toku, you will focus on building, improving, and deploying real-world AI capabilities across speech-to-text, chatbots, and large language model–driven features used in production. This role combines   ...    What you will be doing\n\nApplied AI & Model Development: Train, fine-tune, evaluate, and improve NLP, speech-to-text, and LLM-based models used in production environments Work hands-on with chatbots, summarisation, and language understanding features, including retrieval-augmented generation (RAG) and vector-based retrieval systems   ...    Applied Research & Experimentation: Read, assess, and experiment with relevant AI/ML research and emerging techniques, translating promising ideas into   ...    We’d love to hear from you if you have\n\nCore AI & LLM Expertise: Strong hands-on experience with LLMs, NLP, or speech technologies, including training, fine-tuning, and evaluating models in real-world or production contexts Practical experience with Python-based AI development (e.g. PyTorch and related ecosystems) Applied Research & Fundamentals: Hands-on experience reading, evaluating, and applying AI/ML research (e.g. papers, benchmarks, emerging techniques) and   ...    A strong foundation in AI/ML fundamentals (e.g. mathematics, machine learning concepts, model behaviour and   ...    Tools & Platform Awareness: Familiarity with retrieval-augmented generation (RAG), embeddings, and vector-based retrieval systems Working knowledge of AWS-based environments and AI tooling (e.g. EC2, SageMaker, MLflow, Docker)\n\nWays of Working: A proactive, problem-solving mindset with the ability to identify opportunities for improvement rather than waiting for   ...    Strong collaboration and communication skills when working with engineers across different disciplines\n\nLocation: This is a remote / hybrid role to be based in either The Netherlands (Rotterdam strongly preferred), Singapore or Hong   ...    Toku has been recognised as a LinkedIn Top Startup and by the Financial Times as one of APAC’s Top 500 High Growth Companies. If you’", searched_via='exa'), Job(title='Hugging Face - Current Openings - Jobs By Workable', url='https://apply.workable.com/huggingface/', text='Hugging Face - Current Openings Hugging Face - Current Openings This website uses cookies to improve user’s experience, personalise ads and analyse traffic. You can accept all cookies, decline all optional cookies, or manage your cookie settings. To learn more, view our cookies policy. Cookies settings\nAccept allDecline all', searched_via='exa'), Job(title='Remote LLM Engineer Jobs – Apply Now | RemoteRocketship.com', url='https://www.remoterocketship.com/jobs/llm-engineer/', text="Remote LLM Engineer Jobs – Apply Now | RemoteRocketship.com\n\n# Remote LLM Engineer Jobs ## Search 33 work from home llm engineer positions. Your career in truly remote companies - apply today. Loved by 10,000+ remote workers\n\nFind Your Dream Remote Job\n\nReceive Emails For Remote Jobs 🗣️ LLM Engineer\n\n🌍 Your Location\n\n💵 Minimum Salary\n\n⚪️ Experience\n\nShow all filters Remote only jobs Hybrid jobs Onsite jobs\n\nHelp me find beginner remote jobs\n\n### People also searched for: ai engineer jobs ai research scientist jobs machine learning engineer jobs 33 total jobs\n\n🆕 Date Added\n\n6 new jobs this week ⚡️\n\n100% are NOT on LinkedIn 🚫\n\n\n\n   ...    Job not on LinkedIn\n\n#### Hydra Host\n\n11 - 50\n\n🔧 Hardware\n\n🏢 Enterprise\n\n🤖 Artificial Intelligence   ...    Partner Manager at Hydra Host building strategic relationships within the AI infrastructure ecosystem. Focusing on   ...    🇺🇸 United States – Remote\n\n💵 $100k - $130k / year\n\n💰 $10M Seed Round on 2022-04\n\n⏰ Full Time   ...    ### Machine Learning Engineer – Large Language Models\n\nJob not on LinkedIn\n\n🕒 3 days ago\n\n🕒 3 days ago Job not on LinkedIn\n\n#### John Snow Labs\n\n51 - 200\n\n🤖 Artificial Intelligence\n\n⚕️ Healthcare Insurance 🧬 Biotechnology\n\nWebsite LinkedIn All Job Openings Machine Learning Engineer specializing in large language models for John Snow Labs. Working on AI model training and optimization for healthcare applications in a fully remote setting. 🌏 Anywhere in the World\n\n💵 $30 - $60 / hour\n\n⏳ Contract/Temporary\n\n🟡 Mid-level 🟠 Senior\n\n🗣️ LLM Engineer\n\nC++\n\nPyTorch\n\n\n\n ### AI Engineer – NLP, Large Language Models\n\nJob not on LinkedIn\n\n🕒 3 days ago\n\n🕒 3 days ago   ...    AI Engineer at DOTSOFT focusing on NLP and Large Language Models for innovative solutions. Involvement in R&D projects   ...    🇬🇷 Greece – Remote\n\n⏰ Full Time\n\n🟡 Mid-level\n\n🟠 Senior 🗣️ LLM Engineer\n\nAWS\n\nAzure\n\nCloud\n\nGoogle Cloud Platform\n\nPython\n\nPyTorch\n\nTensorflow\n\n   ...    Member of Technical Staff overseeing AI infrastructure for model training, collaborating with research and product   ...    Senior NLP/LLM Engineer developing AI-driven platforms for social discovery. Focused on natural communication and   ...    General Interest application for potential future opportunities in AI infrastructure related roles. Submit resume if   ...    Infrastructure Product Engineer at Andromeda, building scalable AI infrastructure and collaborating with   ...    Website LinkedIn All Job Openings  Senior Conversational AI Engineer designing and   ...    Generative AI Engineer Virtual Intern in Robert Half's Protiviti Applications department. Design and develop AI-driven   ...    Python\n\nSDLC\n\nSQL\n\nTypeScript\n\n+14 More LLM Engineer Jobs Available!\n\nSign Up Loved by 10,000+ remote workers\n\n## Top Companies Hiring Remote LLM Engineers\n\n### ANRGI TECH\n\nANRGI TECH #### Job Openings\n\n- LLM Engineer Manager\n\n### August Infotech\n\nAugust Infotech #### Job Openings\n\n- Generative AI Engineer\n\n### BPK Technologies\n\nBPK Technologies #### Job Openings  - Senior Software Engineer, Generative AI\n\n### Codvo.ai\n\nCodvo.ai #### Job Openings\n\n- Senior Generative AI Engineer\n\n### Cognitx\n\nCognitx\n\n#### Job Openings - AI / LLM Engineering – Werkstudent\n\n### N-Power Medicine, Inc.\n\nN-Power Medicine, Inc.   ...    ## Remote llm engineer salary expectations  The average salary for remote llm engineers is $171,072 per year. This is based on data from 160 job openings. Our advanced AI searches the internet for remote job openings and posts them on   ...    Below is a breakdown of salary data by years of experience:\n\n⚪️ Entry-level LLM Engineer (0 yrs) 🟢 Junior LLM Engineer (1-2 yrs)  | Experience | Number of roles analyzed | Average Salary |\n| --- | --- | --- |   ...    What skills do you need to get a remote llm engineer job?  You need strong programming skills in languages like Python, proficiency in machine learning frameworks (e.g., TensorFlow, PyTorch), expertise in natural language processing (NLP),   ...   ", searched_via='exa'), Job(title='Job openings in AI and ML engineering - Facebook', url='https://www.facebook.com/groups/1407434203194440/posts/1844881486116374/', text="Tuyển dụng DataOps, MLOps, AI, Data Engineer, Data Scientist, Data Analyst | # **We're hiring AIE/ML ** | Facebook # Tuyển dụng DataOps, MLOps, AI, Data Engineer, Data Scientist, Data Analyst | # **We're hiring AIE/ML ** 34.0K members\n\nJoin group Log in or sign up for Facebook to connect with friends, family and people you know.\n\nLog In\n\nor Create new account", searched_via='exa'), Job(title='Junior AI Developer - ForageAI', url='https://forage.ai/job-opportunities/junior-ai-developer/', text='Junior AI Developer - ForageAI --\n\nForage AI Careers!\n\n# Junior AI Developer\n\nTechnology\n\nFull Time\n\nRemote Apply for this job We are seeking a Junior AI Developer to build and optimize LLM-based applications for data extraction, XPath generation, and autonomous AI agents. The ideal candidate should have hands-on experience with large language models, expertise in Python, and a passion for solving AI-driven challenges in an agile environment. ## Key Responsibilities: Develop and deploy LLM-based applications for data extraction, XPath generation, and autonomous AI agents. Engage in prompt engineering, model fine-tuning, and rapid prototyping to enhance AI performance. Integrate LLM functionalities into existing systems using APIs. Stay updated with the latest advancements in LLMs and AI to propose innovative solutions. Collaborate with cross-functional teams to implement AI-driven automation.\n\n- Blog ## Required Skills & Qualifications:\n\n1-3 years of experience in AI/ML development, with a focus on NLP and LLMs. Hands-on experience with large language models (e.g., Openai, Claude, Gemini, Deepseek), including prompt engineering and fine tuning. Proficiency in Python and familiarity with ML/NLP frameworks such as Hugging Face Transformers, PyTorch, TensorFlow. Experience with agentic frameworks like Langgraph and CrewAI. Strong problem-solving skills and ability to work in an exploratory, agile environment. Familiarity with API integration and deployment of AI models in production Environments.\n\n## Nice-to-Have Skills: Knowledge of web scraping, data parsing, or autonomous agents. Experience with cloud platforms like AWS, GCP, or Azure. Understanding of vector databases and retrieval-augmented generation (RAG) techniques.   ...    Since this is a completely work-from-home position, you will also require the following – High-speed internet connectivity for video calls and efficient work. Capable business-grade computer (e.g., modern processor, 8 GB+ of RAM, and no other obstacles to interrupted efficient   ...    ## Apply Now Data Store Agriculture Automotive Ecommerce Education Finance & Banking Government & Public Sector Healthcare & Pharmaceuticals Media & Entertainment Real Estate Firmographic Data -- Use Cases', searched_via='exa'), Job(title='Get a job in Prompt Engineering, AI, or ML', url='https://remoteai.io/', text='a job in Prompt Engineering, AI, or ML # Your prime source for jobs and talents in AI, Prompt Engineering , Generative AI , Data Science , Big Data and   ...    - AI & Machine Learning Engineers\n- Data Science & Analytics\n- NLP & Prompt Engineering\n- MLOps & AI Infrastructure   ...    All Experience Levels 🌐 Entry Level / Junior 🎓 Mid-Level / Intermediate 🚀 Senior Level / Expert 👨\u200d💼 Executive Level /   ...    Regions / Remote 🗺️ Remote/Anywherer Africa Asia & Pacific Europe Middle East North America South America Job types 💼 Full Time Part Time Contract Temporary Internship Freelance Reset For You Subscribe Search\n\n \n\n## Latest Talent Ready for Hire Discover our newest AI experts, each already vetted and prepared to join innovative teams. Start browsing now to find   ...    #### Oladapo A. Senior AI Prompt Engineer | LLM Optimization & Workflow Automation | Remote-First | Creative & Analytical   ...    Intermediate / Mid Level\n\n##### Role Interests: - prompt engineering\n- chatgpt\n- Analyst\n- ml (machine learning)\n- ai jobs\n\n##### Skills: - prompt design & refinement\n- llm optimization (chatgpt, claude, gemini, mistral)   ...    - data analysis & pattern recognition\n- analytical report writing\n- logical & creative thinking\n- remote collaboration   ...    Hire Me Now\n\n#### Jj H. Bridging artificial intelligence and computer engineering to build smarter systems.\n\nIntermediate / Mid Level ##### Role Interests:\n\n- chatgpt\n- ai jobs\n- AI Marketing\n- generative ai\n- computer vision\n\n##### Skills:   ...    Hire Me Now\n\n#### Daria\n\nChatGPT, n8n, Kling AI, Ideogram, Canva, n8n\n\nBeginner / Entry Level ##### Role Interests:\n\n- ai jobs\n- prompt engineering\n- chatgpt\n- AI Marketing\n\n##### Skills: - building ai agents (using n8n & apis)\n- conflict resolution & feedback handling   ...    Hire Me Now\n\n \n\n \n\n \n\n#### White Bridge LTD\n\n## Junior Crypto Analyst & Trader (Remote) - Analyst\n- analyst\n- chatgpt\n\nApply Now ->\n\n$65k - $80k Analyst Analyst #### HeartStamp\n\n## Prompt Engineer (Generative AI) - Prompt\n- Part Time - prompt engineering (image & video), diffusion models, inpainting & outpainting, lora, controlnet, comfyui, flux /   ...    Apply Now ->\n\nRemote $15k - $30k USD Mid-Level / Intermediate 🚀 #### Scale AI\n\n## Senior/Staff Machine Learning Research Scientist Generative AI - Generative AI\n- Full Time\n- aws\n- computer science\n- computer vision\n- deep learning\n- emnlp\n- gcp\n- generative ai   ...    - generative ai\n- generative modeling\n- llms\n- machine learning   ...    ## Director, Machine Learning - ML (Machine Learning)\n- Full Time\n- asr\n- engineering\n- gcp\n- golang\n- graphql\n- javascript\n- kubernetes - machine learning\n- nlp\n- pipelines   ...    #### Infotel UK\n\n## Data Analyst - Analyst\n- Full Time\n- computer science\n- data analysis\n- data visualization\n- mathematics\n- power bi\n- python\n- r   ...    Apply Now -> Chennai - Tamil Nadu - Remote, India $68k - $110k USD Entry Level / Junior 🎓 #### Replicant\n\n## Senior Software Engineer II, ML team - Engineering\n- Full Time\n- architecture\n- chatbots\n- chatgpt\n- conversational ai\n- engineering\n- gpt\n- llms - machine learning\n- nlg\n- python Apply Now -> Remote US and Canada, United States $52k - $98k USD Senior-level 👨\u200d💼   ...    Hiring a Senior AI engineer through RemoteAI', searched_via='exa'), Job(title='Innodata hiring AI/ML Research Engineer, LLM Post-Training & Evaluation • Remote (Work from Home) | Himalayas', url='https://himalayas.app/companies/innodata/jobs/ai-ml-research-engineer-llm-post-training-evaluation', text="Innodata hiring AI/ML Research Engineer, LLM Post-Training & Evaluation • Remote (Work from Home) | Himalayas\n\nIN # AI/ML Research Engineer, LLM Post-Training & Evaluation At Innodata, we're passionate about bridging the gap between data and innovative technology.\n\nInnodata 5000+\n\nUnited States only\n\nStay safe on Himalayas   ...    in 13 cities around the world, we are the AI technology solutions provider-of-choice to 4 out of 5 of the world’s   ...    ### Position Summary: Innodata is expanding its team of technical experts in LLM training, post-training, and evaluation systems. As an AI/ML Research Engineer, LLM Training & Evaluation, you will build and optimize the technical foundations that   ...    This role is ideal for someone who has hands-on experience fine-tuning and evaluating large language models (and   ...    ### Who We’re Looking For: You have at least 2-3 years of relevant experience in machine learning engineering, applied ML systems, or research engineering, with substantial hands-on work in LLMs and multimodal foundation models. You have built, adapted, or   ...    Contribute to best practices and standards for LLM training, evaluation, and quality assurance across projects Mentor junior engineers and contribute to technical design reviews, documentation, and engineering rigor across the team ### Requirements BS/MS/PhD in Computer Science, Machine Learning, AI, Applied Mathematics, or a related quantitative technical field   ...    2-3 years of relevant industry or research engineering experience in ML/AI systems Hands-on experience with LLM training / fine-tuning / post-training, including at least one of: ### supervised fine-tuning (SFT)\n\npreference optimization (e.g., DPO or related methods) ### RLHF / RLAIF-style workflows\n\ntask- or domain-adaptation of foundation models Strong programming skills in Python and experience building production-quality ML code Experience with modern ML frameworks (e.g., PyTorch, JAX, TensorFlow) and model libraries/tooling (e.g., Hugging Face   ...    ### Technical Skills\n\n### ML / LLM Engineering   ...    Experience with multimodal model training/evaluation (text + image/audio/video) Experience with long-context evaluation and/or model adaptation for long-context tasks Experience with agentic or multi-turn evaluation harnesses, tool-use simulation, or interactive environment testing   ...    Please be aware of recruitment scams involving individuals or organizations falsely claiming to represent employers.   ...    ## About the job\n\n### Apply before\n\nApr 28, 2026\n\n### Posted on\n\nFeb 27, 2026\n\n### Job type\n\nFull Time ### Experience level\n\nMid-level\n\n### Education\n\nBachelor degree\n\nPostgraduate degree\n\n### Experience\n\n2 years minimum ### Location requirements\n\nSuggest an edit\n\nUnited States\n\n### Hiring timezones\n\nShow UTC offsets United States +/- 0 hours\n\n### Job categories Machine Learning Engineer AI Research Engineer LLM Engineer [NLP   ...    Large Language Models Machine Learning Python PyTorch   ...    At Innodata, we're passionate about bridging the gap between data and innovative technology. With over 35 years of   ...    United States +/- 0 hours\n\n### Job categories Machine Learning Engineer AI Research Engineer LLM Engineer [NLP   ...    Claim this profile\n\n## Innodata\n\nIN\n\n### Company size\n\n5000+ employees\n\n### Founded in\n\n1988   ...    ### Employees live in\n\nUnited States\n\nView company profile\n\n## Similar remote jobs Here are other jobs you might want to apply for.\n\nView all remote jobs\n\n## 16 remote jobs at Innodata Explore the variety of open remote roles at Innodata, offering flexible work options across multiple disciplines and   ...    View all jobs at Innodata\n\nTop remote companies\n\n## Remote companies like Innodata Find your next opportunity by exploring profiles of", searched_via='exa'), Job(title='Find a Job in AI - DeepRec.ai', url='https://www.deeprec.ai/jobs', text='Find a Job in AI | DeepRec.ai\n\n# FIND YOUR NEXT ROLE IN AI\n\nDive into our Deep Tech jobs. 5 miles10 miles20 miles30 miles40 miles50 miles\n\nSearch\n\nFilters\n\nNo jobs exist matching your query.', searched_via='exa'), Job(title='[Hiring] Gen AI / LLM Engineer @Weekday AI', url='https://remotive.com/remote/jobs/ai-ml/gen-ai-llm-engineer-3535418', text="[Hiring] Gen AI / LLM Engineer @Weekday AI\n\nBack to Remote jobs AI / ML Gen AI / LLM Engineer @Weekday AI\n\nAI / ML\n\nSalary inr 800,000 - 2..\n\nRemote Location\n\nIndia Job Type full-time\n\nPosted 3wks ago\n\n# [Hiring] Gen AI / LLM Engineer @Weekday AI 3wks ago - Weekday AI is hiring a remote Gen AI / LLM Engineer. 💸 Salary: inr 800,000 - 2,000,000 per year 📍Location:   ...    We are seeking a highly skilled Gen AI / LLM Engineer with hands-on experience in designing, building, and deploying applications powered by Large Language Models. This role focuses on end-to-end development of scalable GenAI solutions   ...    - Collaborate closely with product, data, and engineering teams to deliver production-ready AI solutions.   ...    - Integrate LLM-based solutions with backend services, APIs, and existing systems. - Build and manage RAG pipelines using vector databases for efficient information retrieval. - Implement prompt engineering, prompt optimization, and systematic evaluation techniques to improve output quality. - Work with state-of-the-art models including OpenAI, Azure OpenAI, Anthropic, LLaMA, Mistral, or equivalent open-source and commercial LLMs. - Design, develop, and deploy LLM-driven applications such as chatbots, copilots, autonomous agents, and Retrieval-Augmented Generation (RAG) systems.   ...    - Familiarity with containerization and orchestration tools like Docker and Kubernetes (preferred).   ...    - Experience building or working with multi-agent systems.   ...    Benefits - Hands-on involvement in building scalable, real-world AI solutions.   ...    Similar Remote Jobs\n\nAI-Native Cloud Infrastructure Generalist (m/f/d) • shopware AG shopware AG AI / ML Europe Germany\n\nNew\n\nApply See more AI Internet Rater • Welo Data Welo Data\n\nAI / ML$14.5/hour USA Only\n\n2wks ago Apply See more\n\nSr/Staff AI Engineer • BNSF Railway BNSF Railway AI / ML$165k - $300k USA Only\n\n4wks ago\n\nApply See more\n\nKickstart Your Job Search ⚡ 11,201 remote jobs added this week You're seeing 0.4% of available roles Unlock 134,421 jobs →   ...    | Be aware of the location restriction for this remote position: India |\n| --- | | ‼ | Beware of scams! When applying for jobs, you should NEVER have to pay anything. Learn more.️ | Back to Remote jobs AI / ML\n\nGen AI / LLM Engineer @Weekday AI\n\nAI / ML Salary inr 800,000 - 2..\n\nRemote Location\n\nIndia\n\nJob Type full-time\n\nPosted 3wks ago   ...    Access 134,421+ vetted remote jobs and get daily alerts.\n\n4.9 ★★★★★ from 500+ reviews\n\nUnlock All Jobs Now   ...    Find Remote Jobs\n\nRemotive Jobs Public API& - RSS Feeds\n- Remote Work Statistics Hiring Trends\n- Remote Job Search Tips   ...    Hiring Remotely - Help Center for Recruiters\n- [", searched_via='exa'), Job(title='[Hiring] Junior AI Engineer @Tria Federal', url='https://remotive.com/remote/jobs/ai-ml/junior-ai-engineer-4063502', text="[Hiring] Junior AI Engineer @Tria Federal\n\nBack to Remote jobs AI / ML Junior AI Engineer @Tria Federal\n\nAI / ML\n\nSalary unspecified\n\nRemote Location\n\n🇺🇸 USA Only Job Type full-time\n\nPosted 5d ago\n\n# [Hiring] Junior AI Engineer @Tria Federal 5d ago - Tria Federal is hiring a remote Junior AI Engineer. 💸 Salary: unspecified 📍Location: USA\n\nRole Description Tria Federal is assembling a small, high-autonomy team of Junior AI Engineers to design and build agentic systems, with   ...    Must be a U.S. citizen due to the security clearance required for this position.\n\nResponsibilities - Build intelligent agents that plan, reason, and interact with users, MCP Servers and APIs, using evolving agentic   ...    - Engineer end-to-end products — from Python or Node.js backends to React or Angular frontend applications that embed   ...    - Integrate and experiment with leading AI platforms and Foundational Models to design multi-agent workflows and retrieval-augmented solutions.   ...    Qualifications - 2–3 years of hands-on experience building and deploying full-stack applications (Python, TypeScript, Node.js, React/Angular). - Practical experience with LLM APIs and generative AI frameworks, ideally having built or experimented with agentic   ...    - Understanding of data and API orchestration, including prompt management, evals, RAG, context handling, and   ...    Similar Remote Jobs\n\nAI Internet Rater • Welo Data Welo Data AI / ML$14.5/hour USA Only\n\n2wks ago\n\nApply See more Audio AI Trainer • Anuttacon Anuttacon\n\nAI / ML$25/hour Worldwide\n\n1wk ago   ...    ⚡ 12,023 remote jobs added this week You're seeing 0.4% of available roles Unlock 144,278 jobs →   ...    | 🇺🇸 | Be aware of the location restriction for this remote position: USA Only |\n| --- | --- | | ‼ | Beware of scams! When applying for jobs, you should NEVER have to pay anything. Learn more.️ | Back to Remote jobs AI / ML\n\nJunior AI Engineer @Tria Federal\n\nAI / ML Salary unspecified\n\nRemote Location\n\n🇺🇸 USA Only\n\nJob Type full-time\n\nPosted 5d ago Apply for this position Save job Saved\n\nTrack application\n\nDid not apply ✓\n\nApplied ✓\n\nSent Follow-Up ✓   ...    | 🇺🇸 | Be aware of the location restriction for this remote position: USA Only |\n| --- | --- |   ...    Access 144,278+ vetted remote jobs and get daily alerts.\n\n4.9 ★★★★★ from 500+ reviews\n\nUnlock All Jobs Now   ...    Find Remote Jobs\n\nRemotive Jobs Public API&   ...    Hiring Remot", searched_via='exa')
]

# %%
len(total_jobs)
# Out:
# 54

# %%
from collections import Counter

def filter_jobs(jobs) -> List[Job]:
    """
    Filter out data that should be excluded in order to reduce the workload of LLM Evaluator (Save costs and improve latency)
    """

    filtered_jobs = []

    EXCLUDING_SITES = ["linkedin.com", "indeed.com", "ziprecruiter.com", "glassdoor.com"]
    EXCLUDING_WORDS = ["senior", "head", "lead", "principal", "director", "manager"]

    seen_urls = set() 
    
    for job in jobs:
        
        # Skip duplicate URLs
        if job.url in seen_urls:
            continue
        seen_urls.add(job.url)
        
        # First filter out URLs that point to these general job platforms that unlikely offer global/worldwide remote roles  
        if not any(domain in job.url.lower() for domain in EXCLUDING_SITES): 
            
            # Additionally, filter out data that contains these words on its title
            if not any(word in job.title.lower() for word in EXCLUDING_WORDS): 
                filtered_jobs.append(job)

    return filtered_jobs

# %%
len(filter_jobs(total_jobs))
# Out:
# 34

# %%
filter_jobs(total_jobs)[0]
# Out:
# Job(title='Job Application for Staff AI Engineer at Clarity AI', url='https://boards.greenhouse.io/clarityai/jobs/4802689101', text=None, searched_via='serp')

# %% [markdown]
# ## Check if including Indeed/LinkedIn/ZipRecruiter

# %%
count = 0

for item in filter_jobs(total_jobs):
    if "indeed.com" in item.url.lower():
        count += 1
        
print(count)
# Out:
# 0
